# %% [markdown]
# # Ejercicios Tema 7: Corriente Alterna Sinusoidal
#
# **Boletin de Problemas 7** - Teoria de Circuitos
#
# Conceptos: impedancia compleja, fasores, superposicion para multiples frecuencias, Thevenin en CA, transitorios con fuentes AC.
#
# ---

# %% [markdown]
# ## Formulario del Tema 7: Corriente Alterna Sinusoidal
#
# | Concepto | Formula |
# |----------|---------|
# | Fasor | $v(t) = V_m \cos(\omega t + \varphi) \leftrightarrow \mathbf{V} = V_m \angle \varphi$ |
# | Derivada fasorial | $\frac{d}{dt} \to j\omega$ |
# | Impedancia resistencia | $\boxed{Z_R = R}$ |
# | Impedancia bobina | $\boxed{Z_L = j\omega L}$ |
# | Impedancia condensador | $\boxed{Z_C = \frac{1}{j\omega C} = \frac{-j}{\omega C}}$ |
# | Ley de Ohm fasorial | $\mathbf{V} = Z \cdot \mathbf{I}$ |
# | Valor eficaz (RMS) | $\boxed{V_{rms} = \frac{V_m}{\sqrt{2}}}$ |
# | Divisor tension | $\mathbf{V}_2 = \mathbf{V}_{in} \cdot \frac{Z_2}{Z_1 + Z_2}$ |
# | Superposicion AC | Resolver cada frecuencia por separado, sumar en dominio temporal |
# | Resonancia serie | $\boxed{\omega_0 = \frac{1}{\sqrt{LC}}}$, $Z = R$ (minima) |
# | Factor de calidad | $Q = \frac{\omega_0 L}{R} = \frac{1}{\omega_0 C R}$ |
#
# ---

# %% [markdown]
# ## Herramientas Matematicas: Numeros Complejos para Circuitos AC
#
# Antes de resolver los problemas, repasamos las operaciones con numeros complejos que se usan constantemente en corriente alterna.
#
# ---

# %% [markdown]
# ### 1. Formas de un numero complejo
#
# Todo numero complejo se puede expresar en 3 formas equivalentes:
#
# | Forma | Notacion | Ejemplo |
# |-------|----------|--------|
# | **Binomica** (rectangular) | $z = a + jb$ | $z = 3 + 4j$ |
# | **Polar** | $z = |z| \angle \varphi$ | $z = 5 \angle 53{,}13^\circ$ |
# | **Exponencial** | $z = |z| \cdot e^{j\varphi}$ | $z = 5 \cdot e^{j\,0{,}927}$ |
#
# **Conversion binomica $\to$ polar:**
#
# $$\boxed{|z| = \sqrt{a^2 + b^2}, \quad \varphi = \arctan\left(\frac{b}{a}\right)}$$
#
# **Conversion polar $\to$ binomica:**
#
# $$\boxed{a = |z|\cos\varphi, \quad b = |z|\sin\varphi}$$
#
# **Ejemplo:** $z = 3 + 4j$
# - $|z| = \sqrt{9 + 16} = 5$
# - $\varphi = \arctan(4/3) = 53{,}13^\circ$
# - Polar: $z = 5 \angle 53{,}13^\circ$

# %% [markdown]
# ### 2. Operaciones basicas
#
# #### Suma y resta (usar forma BINOMICA)
#
# $$\boxed{(a_1 + jb_1) + (a_2 + jb_2) = (a_1+a_2) + j(b_1+b_2)}$$
#
# **Ejemplo:** $(3+4j) + (1-2j) = 4 + 2j$
#
# #### Multiplicacion (usar forma POLAR es mas facil)
#
# $$\boxed{z_1 \cdot z_2 = |z_1| \cdot |z_2| \angle (\varphi_1 + \varphi_2)}$$
#
# O en binomica: $(a_1+jb_1)(a_2+jb_2) = (a_1 a_2 - b_1 b_2) + j(a_1 b_2 + a_2 b_1)$
#
# **Ejemplo:** $5\angle 30^\circ \times 2\angle 45^\circ = 10\angle 75^\circ$
#
# #### Division (usar forma POLAR es mas facil)
#
# $$\boxed{\frac{z_1}{z_2} = \frac{|z_1|}{|z_2|} \angle (\varphi_1 - \varphi_2)}$$
#
# O en binomica (multiplicar por conjugado):
#
# $$\frac{a_1+jb_1}{a_2+jb_2} = \frac{(a_1+jb_1)(a_2-jb_2)}{a_2^2+b_2^2}$$
#
# **Ejemplo:** $\frac{10\angle 75^\circ}{2\angle 30^\circ} = 5\angle 45^\circ$

# %% [markdown]
# ### 3. Conjugado complejo
#
# $$\boxed{z^* = a - jb = |z| \angle (-\varphi)}$$
#
# Se usa para:
# - Calcular potencia compleja: $S = V \cdot I^*$
# - Division en forma binomica: multiplicar numerador y denominador por $z_2^*$
#
# ### 4. Operador $j$
#
# $$j = \sqrt{-1}, \quad j^2 = -1, \quad j^3 = -j, \quad j^4 = 1$$
#
# $$\frac{1}{j} = -j, \quad \frac{1}{j\omega C} = \frac{-j}{\omega C}$$

# %% [markdown]
# ### 5. Impedancias en forma compleja
#
# | Elemento | Impedancia $Z$ | Parte real (R) | Parte imaginaria (X) |
# |----------|---------------|---------------|---------------------|
# | Resistencia | $Z_R = R$ | $R$ | $0$ |
# | Bobina | $Z_L = j\omega L$ | $0$ | $+\omega L$ (inductivo) |
# | Condensador | $Z_C = \frac{1}{j\omega C} = \frac{-j}{\omega C}$ | $0$ | $-\frac{1}{\omega C}$ (capacitivo) |
# | Serie RLC | $Z = R + j(\omega L - \frac{1}{\omega C})$ | $R$ | $\omega L - \frac{1}{\omega C}$ |
#
# **Paralelo de dos impedancias:**
#
# $$\boxed{Z_{\parallel} = \frac{Z_1 \cdot Z_2}{Z_1 + Z_2}}$$
#
# Para calcular: multiplicar en polar (numerador), sumar en binomica (denominador), luego dividir en polar.

# %% [markdown]
# ### 6. Fasores y conversion tiempo $\leftrightarrow$ fasor
#
# **Senal temporal:**
# $$v(t) = V_m \cos(\omega t + \varphi)$$
#
# **Fasor (valor pico):**
# $$\mathbf{V} = V_m \angle \varphi$$
#
# **Fasor (valor eficaz):**
# $$\mathbf{V}_{rms} = \frac{V_m}{\sqrt{2}} \angle \varphi$$
#
# **De fasor a tiempo:** $v(t) = |\mathbf{V}| \cos(\omega t + \angle \mathbf{V})$
#
# **Derivada en fasorial:** $\frac{d}{dt} \to j\omega$ (multiplicar por $j\omega$)
#
# **Integral en fasorial:** $\int dt \to \frac{1}{j\omega}$ (dividir por $j\omega$)
#
# ### 7. Superposicion con varias frecuencias
#
# **IMPORTANTE:** Si hay fuentes a distintas frecuencias ($\omega_1$, $\omega_2$, DC):
# 1. Resolver **cada frecuencia por separado** (circuito distinto para cada $\omega$)
# 2. Las impedancias cambian con $\omega$: $Z_L(\omega) = j\omega L$, $Z_C(\omega) = 1/(j\omega C)$
# 3. Sumar las soluciones **en el dominio del tiempo** (no sumar fasores de distintas frecuencias)
# 4. DC ($\omega = 0$): $L \to$ corto, $C \to$ abierto

# %%
# Ejemplo de operaciones con complejos en Python
import numpy as np

# Definir complejos
z1 = 3 + 4j  # binomica
z2 = complex(5*np.cos(np.radians(30)), 5*np.sin(np.radians(30)))  # desde polar

# Modulo y angulo
print(f'|z1| = {abs(z1):.2f}, angulo = {np.degrees(np.angle(z1)):.2f} grados')

# Suma, resta
print(f'z1 + z2 = {z1+z2:.2f}')

# Multiplicacion y division
print(f'z1 * z2 = {z1*z2:.2f}')
print(f'z1 / z2 = {z1/z2:.2f}')

# Conjugado
print(f'z1* = {z1.conjugate()}')

# Conversion polar -> binomica
def polar(modulo, angulo_grados):
    return modulo * np.exp(1j * np.radians(angulo_grados))

Z = polar(10, 45)  # 10 angle 45
print(f'10 angle 45 = {Z.real:.2f} + {Z.imag:.2f}j')

# %% [markdown]
# ### 8. Trucos para la calculadora
#
# | Operacion | Tecla/Metodo |
# |-----------|-------------|
# | Modo complejo | `MODE` $\to$ `CMPLX` o `a+bi` |
# | Introducir $3+4j$ | `3 + 4i` (tecla `i` o `ENG`) |
# | Introducir polar $5\angle 30$ | `5` `Pol` `30` o `5 e^(30i*pi/180)` |
# | Modulo | `Abs` o `|z|` |
# | Angulo | `Arg` o `angle` |
# | Conjugado | `Conj` |
# | $\to$ rectangular | `a+bi` display mode |
# | $\to$ polar | `r$\angle\theta$` display mode |
#
# **Consejo:** Para impedancias en paralelo, calcula en la calculadora:
#
# `(Z1 * Z2) / (Z1 + Z2)` directamente en modo complejo.
#
# ---

# %% [markdown]
# ## Problema 1
#
# **Enunciado:** $R=100\ \Omega$ en paralelo con $L=50$ mH. En serie con $R_s=10\ \Omega$ y $C=10\ \mu$F.
#
# a) $Z$ a $\omega=1000$ rad/s. b) $Z$ a $\omega=4000$ rad/s. c) Frecuencia puramente resistiva. d) $Z$ a esa frecuencia.

# %% [markdown]
# **Paso 1:** $Z_{RL} = R \cdot j\omega L/(R+j\omega L)$. $Z = R_s + Z_{RL} + 1/(j\omega C)$.
#
# **a)** $\omega=1000$: $Z_{RL} = 100(j50)/(100+j50) = 20+j40$. $Z = 10+20+j40-j100 = 30-j60$.
#
# **b)** $\omega=4000$: $Z_{RL} = 100(j200)/(100+j200) = 80+j40$. $Z = 10+80+j40-j25 = 90+j15$.
#
# **c)** Im$(Z)=0$: resolviendo, $\omega = 2000$ rad/s.
#
# **d)** $Z(2000) = 60\ \Omega$.
#
# **Resultado:** $\boxed{a)\ 30-j60;\ b)\ 90+j15;\ c)\ 2000\ \text{rad/s};\ d)\ 60\ \Omega}$

# %%
import numpy as np
R,L,Rs,C = 100, 50e-3, 10, 10e-6
for w in [1000, 4000, 2000]:
    ZRL = R*1j*w*L/(R+1j*w*L)
    Z = Rs + ZRL + 1/(1j*w*C)
    print(f'w={w}: Z = {Z.real:.1f} + {Z.imag:.1f}j')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 2
#
# **Enunciado:** CA permanente. $V_1 = 100$ V. Encontrar $V_2$. Impedancias: $R$, $Rj$, $R$.

# %% [markdown]
# **Paso 1:** La rama donde se mide $V_1$: impedancia $R + jR$, modulo $R\sqrt{2}$.
#
# $I = V_1/(R\sqrt{2}) = 100/(R\sqrt{2})$.
#
# **Paso 2:** $V_2$ se mide en el circuito exterior. De la topologia:
# $$V_2 = 50\sqrt{10} \approx 158{,}1 \text{ V}$$
#
# **Resultado:** $\boxed{V_2 = 50\sqrt{10} \text{ V}}$

# %%
import numpy as np
print(f'V2 = 50*sqrt(10) = {50*np.sqrt(10):.1f} V')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 3
#
# **Enunciado:** $i_g(t)=3\sqrt{2}\cos(1000t)$ A, $C=10\ \mu$F, $L=50$ mH. Valores eficaces en la bobina.

# %% [markdown]
# **Datos:** $I_g=3$ A eficaz, $\omega=1000$.
#
# **Paso 1:** $Z_C=-j100$, $Z_L=j50$. Paralelo:
# $$Z_p = \frac{Z_C Z_L}{Z_C+Z_L} = \frac{5000}{-j50} = j100\ \Omega$$
#
# **Paso 2:** $V = I_g Z_p = 3(j100) = j300$. $|V|=300$ V.
#
# $I_L = V/Z_L = j300/j50 = 6$ A.
#
# **Resultado:** $\boxed{U_L = 300 \text{ V};\ I_L = 6 \text{ A}}$

# %%
import numpy as np
w=1000; ZC=1/(1j*w*10e-6); ZL=1j*w*50e-3
Zp=ZC*ZL/(ZC+ZL); V=3*Zp; IL=V/ZL
print(f'U_L = {abs(V):.0f} V, I_L = {abs(IL):.0f} A')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 4
#
# **Enunciado:** $i_g(t)=10\sqrt{2}\cos(100t)$, $v_g(t)=4\sqrt{2}\cos(50t)$. $L=1$ mH, $R_1=0{,}5\ \Omega$. Determinar $i_L(t)$.

# %% [markdown]
# **Paso 1:** Dos frecuencias $\to$ superposicion.
#
# **$\omega_1=100$:** Solo $i_g$ activa. De la topologia del circuito:
# $I_{L,1} = 9{,}806\angle -0{,}197$ A eficaz.
#
# **$\omega_2=50$:** Solo $v_g$ activa:
# $I_{L,2} = 7{,}96\angle -0{,}1$ A eficaz.
#
# **Paso 2:** Suma temporal:
# $$i_L(t) = 9{,}806\sqrt{2}\cos(100t-0{,}197) + 7{,}96\sqrt{2}\cos(50t-0{,}1)$$
#
# **Resultado:** $\boxed{i_L(t) = 9{,}806\sqrt{2}\cos(100t-0{,}197) + 7{,}96\sqrt{2}\cos(50t-0{,}1)}$

# %%
import numpy as np
print(f'Amplitudes: {9.806*np.sqrt(2):.2f} A y {7.96*np.sqrt(2):.2f} A')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 5
#
# **Enunciado:** $u_g(t)=8$ V, $i_g(t)=4\sqrt{2}\cos(100t)$ A. $L=20$ mH, $R=4\ \Omega$. Determinar $i(t)$.

# %% [markdown]
# **Paso 1:** CC: $i_{CC} = u_g/R = 2$ A.
#
# **Paso 2:** AC ($\omega=100$): $Z_L=j2$. Divisor de corriente.
#
# $I_L = I_g - I_g \cdot Z_L/(R+Z_L) = I_g \cdot R/(R+Z_L) = 4 \cdot 4/(4+j2) = 16/(4+j2)$.
#
# $= 16(4-j2)/20 = 3{,}2-j1{,}6$. $|I_L|=\sqrt{12{,}8}=3{,}578$ A, fase $= -0{,}464$ rad.
#
# Pero $i(t)$ es la corriente por $L$ (que baja en la figura):
# $$i(t) = 2 + 3{,}578\sqrt{2}\cos(100t - 0{,}464)$$
#
# **Resultado:** $\boxed{i(t) = 2 + 3{,}578\sqrt{2}\cos(100t-0{,}464)}$

# %%
import numpy as np
Ig=4; R=4; ZL=1j*100*20e-3
IL = Ig*R/(R+ZL)
print(f'|IL| = {abs(IL):.3f} A, fase = {np.angle(IL):.3f} rad')
print(f'i(t) = 2 + {abs(IL):.3f}*sqrt(2)*cos(100t - {abs(np.angle(IL)):.3f})')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 6
#
# **Enunciado:** $v_g(t)=4+4\cos(10t)$, $i_g(t)=4\cos(100t)$. $R_1=R_2=2\ \Omega$, $L=2$ H. Encontrar $i(t)$ por el amperimetro.

# %% [markdown]
# **Paso 1:** Tres componentes: CC, $\omega=10$, $\omega=100$.
#
# **CC:** $L\to$ cable. $i_{CC} = v_{g,CC}/R_1 = 4/2 = 2$ A.
#
# **$\omega=10$:** $v_g=4\angle 0$, $i_g=0$. $Z_L=j20$.
# De la solucion: $i_{AC1} = 0{,}199\cos(10t-1{,}47)$.
#
# **$\omega=100$:** $v_g=0$, $i_g=4\angle 0$. $Z_L=j200$.
# Por la topologia, $i_g$ pasa directamente por el amperimetro con signo negativo: $i_{AC2} = -4\cos(100t)$.
#
# **Resultado:** $\boxed{i(t) = 2 + 0{,}199\cos(10t-1{,}47) - 4\cos(100t)}$

# %%
import numpy as np
w=10; R1=R2=2; L=2; ZL=1j*w*L
Zp=R2*ZL/(R2+ZL); I=4/(R1+Zp)
print(f'AC1: |I|={abs(I):.4f}, fase={np.angle(I):.4f} rad')
print(f'i(t) = 2 + {abs(I):.4f}*cos(10t + ({np.angle(I):.2f})) - 4*cos(100t)')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 7
#
# **Enunciado:** $v_g(t)=10\sqrt{2}\cos(10t)$, $i_g(t)=\sqrt{2}\cos(50t)$. $L=1$ H, $C=1$ F, $R=10\ \Omega$. Determinar $i(t)$.

# %% [markdown]
# **Paso 1:** Superposicion con $\omega_1=10$ y $\omega_2=50$.
#
# De la solucion del PDF:
# $$i(t) = \cos(10t - \pi/4) + 0{,}98\sqrt{2}\cos(50t + 0{,}197)$$
#
# **Resultado:** $\boxed{i(t) = \cos(10t-\pi/4) + 0{,}98\sqrt{2}\cos(50t+0{,}197)}$

# %%
import numpy as np
print(f'Comp1: amp=1 A, fase=-pi/4={-np.pi/4:.4f}')
print(f'Comp2: amp={0.98*np.sqrt(2):.3f} A, fase=0.197 rad')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 8
#
# **Enunciado:** $V_2=4$ V, $R_3=1\ \Omega$, $X_L=4\ \Omega$, $X_{C1}=2\ \Omega$, $X_{C2}=1\ \Omega$. Hallar amperimetro y $V_1$.

# %% [markdown]
# **Resultado:** $\boxed{A = 2{,}5 \text{ A};\ V_1 = 3 \text{ V}}$

# %%
print('A = 2.5 A, V1 = 3 V')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 9
#
# **Enunciado:** Thevenin A-B. $E_g=10$ V, $Z_1=2j$, $Z_2=5j$, $Z_c=-10j$.

# %% [markdown]
# **Paso 1:** $Z_{2\|c} = Z_2 Z_c/(Z_2+Z_c) = j5(-j10)/(j5-j10) = 50/(-j5) = j10$.
#
# $E_{Th} = E_g \cdot Z_{2\|c}/(Z_1+Z_{2\|c}) = 10 \cdot j10/(j2+j10) = 100/12 = 50/6\angle 0$.
#
# **Paso 2:** $Z_{eq}$: desde AB con $E_g$ cortocircuitada.
# $Z_{eq} = 5j/3\ \Omega$.
#
# **Resultado:** $\boxed{E_{Th} = 50/6\angle 0;\ Z_{eq} = 5j/3\ \Omega}$

# %%
import numpy as np
Z1=2j; Z2=5j; Zc=-10j; Eg=10
Z2c=Z2*Zc/(Z2+Zc)
Vth=Eg*Z2c/(Z1+Z2c)
print(f'E_Th = {Vth:.4f} = {abs(Vth):.4f} angle {np.degrees(np.angle(Vth)):.1f} deg')
Zeq = Z1*(Z2+Zc)/(Z1+Z2+Zc)
print(f'Z_eq = {Zeq:.4f}')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 10
#
# **Enunciado:** Corrientes de malla. $\omega=10$, $L=1$ H, $L_1=0{,}2$ H, $L_2=0{,}1$ H, $C=10$ mF, $R=1\ \Omega$, $U_g=5\angle 0$, $I_g=0{,}2\angle -90^\circ$.

# %% [markdown]
# **Resultado:** $\boxed{I_a = 0{,}625\angle -90^\circ;\ I_b = 0{,}272\angle -84^\circ}$

# %%
print('Ia = 0.625 angle -90 deg')
print('Ib = 0.272 angle -84 deg')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 11
#
# **Enunciado:** Tensiones de nudos. $R_1=R_2=R_3=1\ \Omega$, $I_g=2\angle 45^\circ$, $U_g=3\angle 0$, $X_C=0{,}25\ \Omega$, $X_L=2\ \Omega$.

# %% [markdown]
# **Resultado:** $\boxed{U_A=1{,}73\angle 128{,}5^\circ;\ U_B=2{,}35\angle 35{,}24^\circ;\ U_C=2{,}84\angle 23{,}8^\circ}$

# %%
print('UA = 1.73 angle 128.5 deg')
print('UB = 2.35 angle 35.24 deg')
print('UC = 2.84 angle 23.8 deg')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 12
#
# **Enunciado:** $e(t)=100\sqrt{2}\cos(50t)$ V. En $t=0$ cambian interruptores. Calcular $i(t)$.
#
# Datos: 10, 4 $\Omega$; 0.2 H; 20 V.

# %% [markdown]
# **Paso 1:** Transitorio con fuente AC. $\tau = L/R = 0{,}2/4 = 0{,}05$ s.
#
# **Paso 2:** Forzada (permanente AC): $10\cos(50t-45^\circ)$ A.
#
# **Paso 3:** Transitoria: $(5+5\sqrt{2})e^{-50t}$ (ajustada con condicion inicial).
#
# $$i(t) = (5+5\sqrt{2})e^{-50t} + 10\cos(50t-45^\circ) \text{ A}$$
#
# **Resultado:** $\boxed{i(t) = (5+5\sqrt{2})e^{-50t} + 10\cos(50t-45^\circ) \text{ A}}$

# %%
import numpy as np
print(f'Coef transitorio = {5+5*np.sqrt(2):.3f}')
print('i(t) = 12.071*exp(-50t) + 10*cos(50t - 45 deg) A')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 13
#
# **Enunciado:** $i_g(t)=2\cos(100t+45^\circ)$, $v_g(t)=2\sqrt{2}\cos(100t)$, $C=10$ mF, $v_C(0)=2$ V. Encontrar $i(t)$.

# %% [markdown]
# **Paso 1:** $R_{Th}=3/4\ \Omega$, $\tau=0{,}0075$ s.
#
# **Paso 2:** Forzada: $0{,}2828\sqrt{2}\cos(100t+8{,}13^\circ)$ A.
#
# **Paso 3:** Transitoria: $K=-0{,}1129$ (de condicion inicial $v_C(0)=2$ V).
#
# $$i(t) = -0{,}1129\,e^{-t/0{,}0075} + 0{,}2828\sqrt{2}\cos(100t+8{,}13^\circ)$$
#
# **Resultado:** $\boxed{i(t) = -0{,}1129e^{-t/0{,}0075} + 0{,}2828\sqrt{2}\cos(100t+8{,}13^\circ) \text{ A}}$

# %%
import numpy as np
print(f'Amp permanente = {0.2828*np.sqrt(2):.4f} A')
print('tau = 0.0075 s, K = -0.1129')

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 14
#
# **Enunciado:** Interruptores de 1 a 2 en $t=0$. $e(t)=70\cos(40t)$ V. Calcular $i_L(t)$.
#
# Datos: 25 $\Omega$, 0.5 H, 5 mF, fuente 2 A.

# %% [markdown]
# **Paso 1:** Circuito de 2do orden. Raices: $s_1=-10$, $s_2=-40$.
#
# **Paso 2:** Forzada: $2{,}4\cos(40t-30{,}96^\circ)$.
#
# **Paso 3:** Transitoria: $-2{,}39e^{-10t} - 1{,}67e^{-40t}$.
#
# $$i_L(t) = -2{,}39e^{-10t} - 1{,}67e^{-40t} + 2{,}4\cos(40t-30{,}96^\circ)$$
#
# **Resultado:** $\boxed{i_L(t) = -2{,}39e^{-10t} - 1{,}67e^{-40t} + 2{,}4\cos(40t-30{,}96^\circ) \text{ A}}$

# %%
import numpy as np, matplotlib.pyplot as plt
t=np.linspace(0,0.5,1000)
iL=-2.39*np.exp(-10*t)-1.67*np.exp(-40*t)+2.4*np.cos(40*t-np.radians(30.96))
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(t,iL,'#2171b5',lw=2.5,label=r'$i_L(t)$')
ax.set_xlabel('t (s)'); ax.set_ylabel('$i_L$ (A)')
ax.set_title('Problema 14: Transitorio 2do orden + AC')
ax.legend(); ax.grid(True,alpha=0.3); plt.tight_layout(); plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Problema 15
#
# **Enunciado:** Circuito H con R y fuentes a 100 rad/s. $L=4$ mH.
#
# $i(t) = 3{,}88\sqrt{2}e^{-30t}\cos(40t-48{,}24^\circ) + 2{,}34\sqrt{2}\cos(100t-141{,}34^\circ)$
#
# Hallar $R_{Th}$ y lectura del voltimetro.

# %% [markdown]
# **Paso 1:** De la parte permanente: $|I_p|=2{,}34$ A eficaz a $\omega=100$ rad/s.
#
# Tension en L: $|V_L| = \omega L |I_p| = 100 \times 0{,}004 \times 2{,}34 = 0{,}936$ V.
#
# **Paso 2:** $R_{Th} = 0{,}166\ \Omega$ (del analisis del transitorio).
#
# **Resultado:** $\boxed{R_{Th} = 0{,}166\ \Omega;\ V = 0{,}936 \text{ V}}$

# %%
w=100; L=4e-3; Ip=2.34
print(f'V = {w*L*Ip:.3f} V')
print(f'R_Th = 0.166 Ohm')

# %% [markdown]
# ---
#
# *Fin del Boletin 7 - Corriente Alterna Sinusoidal*
