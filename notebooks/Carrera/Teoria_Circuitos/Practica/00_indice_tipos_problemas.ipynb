# %% [markdown]
# # Indice de Tipos de Problemas - Teoria de Circuitos
#
# **Guia de estudio organizada por conceptos**
#
# Este notebook clasifica los 91 problemas de los 8 boletines por tipo. Para cada tipo se indica:
# - Que concepto practica
# - Que formula clave se usa
# - En que notebook esta resuelto (carpeta `Practica/`)
# - Nivel de dificultad
#
# ---

# %% [markdown]
# ## Tema 1 - Introduccion (6 problemas)
#
# **Notebook:** `01_ejercicios_introduccion.ipynb`
#
# | # | Tipo de problema | Concepto clave | Formula | Dificultad |
# |---|-----------------|---------------|---------|------------|
# | P1 | Calculo de carga y energia desde $i(t)$ | $q = \int i\,dt$, $w = \int p\,dt$ | $q = \frac{1}{2}at^2$, $w = \int u \cdot i\,dt$ | Basico |
# | P2 | Amortizacion / coste energetico | Potencia $\times$ tiempo = energia | $E = P \cdot t$ (kWh) | Basico |
# | P3 | Escribir ecuaciones KCL y KVL | Identificar cortes y bucles | $\sum i_k = 0$ (corte), $\sum v_k = 0$ (bucle) | Basico |
# | P4 | Escribir ecuaciones KCL y KVL (otra topologia) | Mismo concepto, diferente circuito | Idem | Basico |
# | P5 | Hallar tension desconocida con KVL | Aplicar LKT a una malla | $u_3 = -u_1 + u_2 - u_4$ | Basico |
# | P6 | Hallar corriente desconocida con KCL | Aplicar LKC a un nudo | $i_2 = i_T - i_1 - i_3$ | Basico |
#
# ---

# %% [markdown]
# ## Tema 2 - Circuitos Resistivos (10 problemas)
#
# **Notebook:** `02_ejercicios_resistivos.ipynb`
#
# | # | Tipo de problema | Concepto clave | Formula | Dificultad |
# |---|-----------------|---------------|---------|------------|
# | P1 | Superposicion lineal | Activar cada fuente por separado, sumar | $V = V_{(Vg)} + V_{(Ig)}$ | Medio |
# | P2 | Red pasiva + fuente: potencia | Circuito sin fuentes independientes internas | $P = I^2 R$ | Medio |
# | P3 | Superposicion con 2 casos dados | Linealidad: $V = aV_g + bI_g$ | Sistema 2x2 para $a$, $b$ | Medio |
# | P4 | Resistencia equivalente (puente Wheatstone) | Serie, paralelo, Y-$\Delta$ | $R_{eq}$, $P = V^2/R_{eq}$ | Medio |
# | P5 | Pilas en serie: autonomia | Fuentes en serie: $V_{total} = \sum V_i$ | $t = Q/I = \text{mAh} / I$ | Facil |
# | P6 | Potencia de fuentes + lectura instrumentos | $P_{fuente}$, amperimetro y voltimetro | $P = V \cdot I$, balance potencia | Medio |
# | P7 | Red de 4 terminales + interruptor | Deducir parametros del cuadripolo | Datos con/sin interruptor | Medio-Alto |
# | P8 | Potencia y caida de tension $V_{ab}$ | Balance de potencia global | $\sum P_{gen} = \sum P_{dis}$ | Medio |
# | P9 | Resistencias iguales + potencia dada | Simetria para simplificar | $P_R = I_R^2 R$ | Medio |
# | P10 | Condicion para $P_R = 0$ | Relacion $E/I_g$ que anula corriente | Superposicion: $I_R = 0$ | Medio-Alto |
#
# ---

# %% [markdown]
# ## Tema 3 - Thevenin, Norton y Fuentes Reales (13 problemas)
#
# **Notebook:** `03_ejercicios_thevenin_norton.ipynb`
#
# | # | Tipo de problema | Concepto clave | Formula | Dificultad |
# |---|-----------------|---------------|---------|------------|
# | P1 | Thevenin desde medidas indirectas | Deducir $E_{Th}$, $R_{eq}$ de $I$, $P_R$, $\eta$ | $R = P/I^2$, $\eta = R/(R+R_{eq})$ | Medio |
# | P2 | Fuente real + carga: potencia y rendimiento | $P$, $\eta$ con fuente V e I en paralelo | $P = V I$, $\eta = P_{carga}/P_{gen}$ | Medio |
# | P3 | Rendimiento dado $\to$ hallar $R$ | Fuente real de corriente | $\eta = R_g/(R_g + R_{carga})$ | Medio |
# | P4 | Relacion $P/P_{max}$ vs $\eta$ (algebraico) | Demostracion teorica | $P/P_{max} = f(\eta)$ | Medio-Alto |
# | P5 | Interruptor a/b $\to$ hallar R | Dos condiciones = 2 ecuaciones | Sistema 2x2 | Medio |
# | P6 | **Thevenin de circuito complejo (puente)** | $V_{ca}$ por superposicion, $R_{Th}$ desactivando | $V_{ca}$, $R_{Th} = (R_1+R_3)\|(R_2+R_4) + R_5 + R_6$ | **Alto** |
# | P7 | **Norton de circuito complejo** | $I_{cc}$, $R_e$ por divisor de corriente | $R_e$, $I_{cc} = V_{ca}/R_e$ | **Alto** |
# | P8 | Thevenin desde $\eta$ y tension medida | $R_{eq}$ y $V_g$ desde condiciones indirectas | $\eta = R_{carga}/(R_{carga}+R_{eq})$ | Medio-Alto |
# | P9 | Fuente I con interruptor (simbolico) | Resultado en funcion de $V_f$ | Analisis simbolico | Medio |
# | P10 | Bombilla (resistencia no lineal) | $R_{bombilla}$ cambia con temperatura | $R = V^2/P_{nominal}$ | Medio-Alto |
# | P11 | **Thevenin con fuente dependiente (rI)** | $V_{ca}$, $I_{cc}$ con FDT en serie | FDT no se desactiva | **Alto** |
# | P12 | **$R_{eq}$ con fuente dependiente ($V_x/6$)** | Fuente de prueba para hallar $R_{eq}$ | $R_{eq} = V_p/I_p$ | **Alto** |
# | P13 | **Thevenin/Norton con FDCI ($\alpha I$)** | $V_{Th}$, $I_N$, $R_{eq}$ con corriente controlada | Ecuaciones acopladas | **Alto** |
#
# ---

# %% [markdown]
# ## Tema 4 - Ecuaciones de Nudos y Mallas (11 problemas)
#
# **Notebook:** `04_ejercicios_nudos_mallas.ipynb`
#
# | # | Tipo de problema | Concepto clave | Formula | Dificultad |
# |---|-----------------|---------------|---------|------------|
# | P1 | Nudos basico 2x2 | Construir $[G]$ por inspeccion | $[G][V] = [I_s]$, Cramer 2x2 | Medio |
# | P2 | Nudos 3x3 (simetrico) | Construir $[G]$ 3x3, reconocer simetria | Cramer 3x3 o numpy | Medio |
# | P3 | Nudos con transformacion de fuente | $E_g + R_g \to I_{eq} + R_g$ paralelo | Misma topologia que P2 | Medio |
# | P4 | **Supernudo** | $E_g$ entre nudos no-ref: restriccion + KCL superficie | $V_B - V_A = E_g$ + KCL supernudo | **Alto** |
# | P5 | Nudos mixto ($V_g$ fija nudo + $I_g$ entra) | $V_A = E_g$ conocida, resolver resto | Sistema reducido 2x2 | Medio-Alto |
# | P6 | Mallas basico 2x2 | Construir $[R]$ por inspeccion | $[R][I] = [V_s]$, Cramer 2x2 | Medio |
# | P7 | Mallas con $I_g$ que fija una malla | $I_b = I_g$ conocida, resolver resto | Norton $\to$ Thevenin, sistema reducido | Medio |
# | P8 | **Supermalla** | $I_g$ en rama compartida: restriccion + KVL combinada | $I_c - I_b = I_g$ + KVL supermalla | **Alto** |
# | P9 | Mallas mixto ($I_g$ fija + $E_g$ en otra) | $I_b = I_g$, $E_g$ en RHS | Sistema reducido 2x2 | Medio-Alto |
# | P10 | **Fuentes dependientes (numerico)** | FDT + FDI acoplan ecuaciones | Supermalla + control variable | **Alto** |
# | P11 | **Fuentes dependientes (simbolico)** | $\beta V$, $\alpha I$: matriz NO simetrica | Supernudo + expresion de control | **Alto** |
#
# ---

# %% [markdown]
# ## Tema 5 - Componentes Dinamicos (7 problemas)
#
# **Notebook:** `05_ejercicios_componentes_dinamicos.ipynb`
#
# | # | Tipo de problema | Concepto clave | Formula | Dificultad |
# |---|-----------------|---------------|---------|------------|
# | P1 | Asociacion de condensadores | Serie: $1/C_{eq}$, Paralelo: $C_{eq}$ | $C_s = C_1 C_2/(C_1+C_2)$ | Facil |
# | P2 | Asociacion de inductores (sin M) | Serie: $L_{eq}$, Paralelo: $L_{eq}$ | $L_p = L_1 L_2/(L_1+L_2)$ | Facil |
# | P3 | **Inductores acoplados (dot convention)** | Signo de M segun puntos y corrientes | Si mismo comportamiento $\to +M$, distinto $\to -M$ | **Alto** |
# | P4 | Inductores acoplados ($k = 1$, perfecto) | Acoplamiento total, signos distintos | Misma regla del punto | **Alto** |
# | P5 | **4 configuraciones de inductores acoplados** | Serie aditiva/sustractiva, paralelo | $L_{eq} = L_1 + L_2 \pm 2M$ | Medio-Alto |
# | P6 | Descarga RC | Transitorio basico de condensador | $i(t) = i_0 e^{-t/\tau}$, $\tau = RC$ | Medio |
# | P7 | Descarga RL | Transitorio basico de inductor | $i(t) = i_0 e^{-t/\tau}$, $\tau = L/R$ | Medio |
#
# ---

# %% [markdown]
# ## Tema 6 - Transitorios de Corriente Continua (10 problemas)
#
# **Notebook:** `06_ejercicios_transitorios_cc.ipynb`
#
# | # | Tipo de problema | Concepto clave | Formula | Dificultad |
# |---|-----------------|---------------|---------|------------|
# | P1 | DC permanente con L y C | $L \to$ corto, $C \to$ abierto | Circuito resistivo puro | Facil |
# | P2 | DC permanente: hallar R desde energia y potencia | $E = \frac{1}{2}LI^2$, $P = I^2 R$ | Sistema de ecuaciones | Medio |
# | P3 | Energia en permanente desde $\eta$ | $E(\infty)$ desde $E(0)$ y rendimiento | $v_C(\infty)/v_C(0) = 1/\eta$ | Medio |
# | P4 | DC permanente + instrumentos | L=corto cortocircuita resistencias | Simplificacion + lectura | Medio |
# | P5 | Thevenin + energia en bobina | $V_{ca}$, $I_{cc}$ desde $E_L$ y $\eta$ | $I = \sqrt{2E_L/L}$, $\eta = R/(R+R_i)$ | Medio-Alto |
# | P6 | Conmutacion: potencia en $t = 0^+$ | Continuidad $v_C(0^+) = v_C(0^-)$, $i_L(0^+) = i_L(0^-)$ | $P = v \cdot i$ instantanea | Medio-Alto |
# | P7 | Conmutacion: energias en nuevo permanente | Antes/despues del interruptor | $E_L = \frac{1}{2}Li^2(\infty)$ | Medio-Alto |
# | P8 | **Transitorio RL completo** | Formula general de 1er orden | $\boxed{x(t) = x_\infty + (x_0 - x_\infty)e^{-t/\tau}}$ | **Alto** |
# | P9 | Transitorio RL con interruptor | Cond. iniciales + nueva topologia + $R_{Th}$ | $\tau = L/R_{Th}$ del nuevo circuito | **Alto** |
# | P10 | **Transitorio RC completo** | Mismo metodo que P8 pero con condensador | $\tau = R_{Th} \cdot C$ | **Alto** |
#
# ---

# %% [markdown]
# ## Tema 7 - Corriente Alterna Sinusoidal (15 problemas)
#
# **Notebook:** `07_ejercicios_corriente_alterna.ipynb`
#
# | # | Tipo de problema | Concepto clave | Formula | Dificultad |
# |---|-----------------|---------------|---------|------------|
# | P1 | Impedancia equivalente serie/paralelo | $Z = R + jX$, paralelo complejo | $Z_{\parallel} = Z_1 Z_2/(Z_1+Z_2)$ | Medio |
# | P2 | Lectura de voltimetro en AC permanente | Voltimetro mide $V_{rms}$ | $V = |I| \cdot |Z|$ | Medio |
# | P3 | Valores eficaces en L y C | $V_{rms}$, $I_{rms}$ de cada componente | $V_L = |I| \cdot \omega L$ | Medio |
# | P4 | **Superposicion: 2 frecuencias AC** | Resolver cada $\omega$ por separado | $i(t) = i_{\omega_1}(t) + i_{\omega_2}(t)$ | **Alto** |
# | P5 | **Superposicion: DC + AC** | $\omega = 0$ (DC) + $\omega \neq 0$ (AC) | DC: $L$=corto,$C$=abierto; AC: fasorial | **Alto** |
# | P6 | Superposicion: DC + 2 frecuencias | 3 circuitos separados | Sumar en tiempo, NO en fasorial | **Alto** |
# | P7 | Superposicion multi-frecuencia + paralelo | Circuito diferente para cada $\omega$ | Idem | **Alto** |
# | P8 | Instrumentos en AC (amperimetro, voltimetro) | $A$ mide $I_{rms}$, $V$ mide $V_{rms}$ | $I_{rms} = \sqrt{\sum I_k^2}$ si distintas $\omega$ | Medio-Alto |
# | P9 | **Thevenin en AC (fasorial)** | $E_{Th}$, $Z_{eq}$ complejos | Mismo metodo DC pero con $Z$ | Medio-Alto |
# | P10 | **Mallas en AC** | $[Z][I] = [V_s]$ con numeros complejos | Cramer con complejos | Medio-Alto |
# | P11 | **Nudos en AC** | $[Y][V] = [I_s]$ con admitancias | Misma regla: $Y_{ij} = -Y_{rama}$ | Medio-Alto |
# | P12 | **Transitorio + permanente sinusoidal** | Resp. natural $e^{-t/\tau}$ + resp. forzada AC | $i(t) = A e^{-t/\tau} + B\cos(\omega t + \phi)$ | **Muy Alto** |
# | P13 | Transitorio RC + permanente AC | Condicion inicial del condensador | $v_C(0^+) = v_C(0^-)$ + fasorial | **Muy Alto** |
# | P14 | Transitorio RL + conmutacion + AC | 2do orden o desacoplado | Multiple exponenciales + senoidal | **Muy Alto** |
# | P15 | Identificar $R_{Th}$ desde forma de onda | La constante $\tau$ del transitorio revela $R_{Th}$ | $\tau = L/R_{Th}$ del decaimiento | **Alto** |
#
# ---

# %% [markdown]
# ## Tema 8 - Potencia y Trifasicos (19 problemas)
#
# **Notebook:** `08_ejercicios_potencia_trifasicos.ipynb`
#
# | # | Tipo de problema | Concepto clave | Formula | Dificultad |
# |---|-----------------|---------------|---------|------------|
# | P1 | Compensacion reactiva con condensador | Reducir $Q$ anadiendo $C$ en paralelo | $C = (Q_1-Q_2)/(\omega V^2)$ | Medio |
# | P2 | $R$ y $X$ desde $S$ y FP | Impedancia de la carga | $Z = V^2/S^*$, $R = |Z|\cos\varphi$ | Medio |
# | P3 | Compensacion: FP objetivo, hallar Q motor | $Q_{motor}$ desde $P$ y FP con/sin banco | $Q = P \tan\varphi$ | Medio |
# | P4 | Circuito con FP + voltimetro | Deducir $R$, $X_c$ de medidas | $P = I^2 R$, FP $= R/|Z|$ | Medio-Alto |
# | P5 | Instrumentos: vatimetro desde medidas | $W$ y $S$ desde $A_1 = A_2$, $V$ | $W = \text{Re}(V \cdot I^*)$ | Medio-Alto |
# | P6 | FP de zona + instrumentos | Analisis por zonas del circuito | Descomponer en sub-circuitos | Medio-Alto |
# | P7 | **Max potencia CC y AC** | $R_L = R_{Th}$ (CC), $Z_L = Z_{Th}^*$ (AC) | $P_{max} = V_{Th}^2/(4R_{Th})$ | **Alto** |
# | P8 | Hallar $R$ y $V_g$ desde potencia cedida | $P = I^2 R$, $S = V_g I$ | Sistema de ecuaciones | Medio |
# | P9 | **Max potencia en R de carga RC** | Compensar reactiva + igualar R | $X_C = X_g$, $R = R_g$ | **Alto** |
# | P10 | Corrientes y $Q$ desde FP de zona | FP $\to \varphi \to$ relaciones entre $I_1$, $I_2$ | Analisis fasorial parcial | **Alto** |
# | P11 | Potencia compleja cedida por fuente | $S = V \cdot I^*$ directamente | $S = P + jQ$ | Medio |
# | P12 | $Z$ para max potencia + instrumentos | $Z = Z_{Th}^*$, luego calcular $A$ y $V$ | Conjugado + corriente resultante | **Alto** |
# | P13 | Instrumentos con fuentes dependientes | Vatimetro y amperimetro con $I_g$ | $W = \text{Re}(V_{12} \cdot I^*)$ | **Alto** |
# | P14 | Suma de 3 cargas: P, Q, FP total | $P_{total} = \sum P_i$, $Q_{total} = \sum Q_i$ | $\text{FP} = P/\sqrt{P^2+Q^2}$ | Medio |
# | P15 | FP de zona enmarcada + potencias fuente | Zona parcial con $X_L$, $X_C$, $R$ | Descomponer y analizar | Medio-Alto |
# | P16 | **Compensacion individual de 2 motores** | Un $C$ por motor, calcular $I$ antes/despues | $C = P(\tan\varphi_1-\tan\varphi_2)/(\omega V^2)$ | **Alto** |
# | P17 | **Transformador: $C$ reflejada al primario** | Impedancia se escala por $n^2$ | $C' = C/n^2$ (condensador), $Z' = n^2 Z$ | Medio-Alto |
# | P18 | **Transformador: $L$ acoplada reflejada** | Inductores en secundario vistos desde primario | $L' = n^2 L_s$ | Medio-Alto |
# | P19 | **Transformador: Thevenin reflejado** | $V_{Th}'$, $R_{Th}'$ vistos desde primario | $V' = nV$, $R' = n^2 R$ | Medio-Alto |
#
# ---

# %% [markdown]
# ## Tipos estrella (mas frecuentes en examen)
#
# | Concepto | Donde practicarlo | Formula clave |
# |----------|-------------------|---------------|
# | **KCL y KVL** | T1-P3,P5,P6 | $\sum i = 0$, $\sum v = 0$ |
# | **Superposicion** | T2-P1,P3; T7-P4,P5,P6 | Activar cada fuente por separado |
# | **Thevenin/Norton** | T3-P1,P6,P7,P11 | $V_{Th} = V_{ca}$, $R_{Th}$, $I_N = V_{Th}/R_{Th}$ |
# | **Nudos [G][V]=[Is]** | T4-P1,P2,P4 | $G_{ii}$ = sum conductancias, $G_{ij} = -G_{rama}$ |
# | **Mallas [R][I]=[Vs]** | T4-P6,P8,P9 | $R_{ii}$ = sum resistencias, $R_{ij} = -R_{compartida}$ |
# | **Supernudo** | T4-P4 | Restriccion $V_a-V_b = V_s$ + KCL superficie |
# | **Supermalla** | T4-P8 | Restriccion $I_a-I_b = I_s$ + KVL contorno |
# | **Fuentes dependientes** | T3-P11,P12,P13; T4-P10,P11 | No desactivar, expresar control en incognitas |
# | **Dot convention (M)** | T5-P3,P4,P5 | Mismo comportamiento = $+M$, distinto = $-M$ |
# | **Transitorio 1er orden** | T6-P8,P9,P10 | $x(t) = x_\infty + (x_0-x_\infty)e^{-t/\tau}$ |
# | **Fasores e impedancia** | T7-P1,P9,P10,P11 | $Z_R=R$, $Z_L=j\omega L$, $Z_C=1/(j\omega C)$ |
# | **Superposicion multi-$\omega$** | T7-P4,P5,P6,P7 | Resolver cada $\omega$ por separado, sumar en tiempo |
# | **Transitorio + permanente AC** | T7-P12,P13,P14 | $x(t) = Ae^{-t/\tau} + B\cos(\omega t + \phi)$ |
# | **Potencia compleja** | T8-P11 | $S = P+jQ = V \cdot I^*$ |
# | **Max transferencia potencia** | T3-P1; T8-P7,P9 | CC: $R_L=R_{Th}$, AC: $Z_L = Z_{Th}^*$ |
# | **Compensacion reactiva** | T8-P1,P3,P16 | $C = (Q_1-Q_2)/(\omega V^2)$ |
# | **Transformador** | T8-P17,P18,P19 | $Z' = n^2 Z$, $V' = nV$ |
