# %% [markdown]
# # Formulario Completo - Teoria de Maquinas y Mecanismos
#
# **Teoria de Mecanismos - GIERM**
#
# ---
#
# Referencia rapida de **todas las formulas** del curso, organizadas por tema.
#
# ## Objetivos
#
# - Tener en un solo lugar **todas las expresiones** necesarias para resolver problemas de mecanismos
# - Servir como **chuleta de examen**: buscar la formula, sustituir datos y resolver
# - Cubrir los 5 temas + apendice de solido rigido + vibraciones
# - Incluir una **guia rapida** de que formula usar en cada tipo de problema

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# ---
#
# ## 1. Tema 1 - Introduccion y Grados de Libertad
#
# Criterios de movilidad, condicion de Grashof y tipos de pares cinematicos.

# %% [markdown]
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Gruebler (GDL plano)** | $\boxed{G = 3(N-1) - 2g - h}$ | $N$: eslabones, $g$: pares inferiores (2 GDL restringidos), $h$: pares superiores (1 GDL restringido) |
# | **Par N-ario** | Un par que conecta $n$ eslabones elimina $2(n-1)$ GDL | Par binario: $n=2$, par ternario: $n=3$, etc. |
# | **Tipos de par inferior** | Rotacion (R), Prismático (P), Cilindrico (C), Esférico (S), Helicoidal (H), Plano (E) | En plano solo R y P; ambos eliminan 2 GDL |
# | **Par superior (contacto)** | Leva, engranaje (contacto puntual/lineal) | Elimina 1 GDL (solo deslizamiento tangencial) |
# | **Condicion de Grashof** | $\boxed{s + l \leq p + q}$ | $s$: eslabon mas corto, $l$: mas largo, $p,q$: restantes. Si se cumple, al menos una manivela completa |
# | **Angulo de transmision** | $\boxed{\mu = \angle(\vec{v}_{\text{salida}},\, \vec{F}_{\text{transmitida}})}$ | Optimo: $\mu \to 90°$. Minimo admisible $\mu_{\min} \approx 40°$ |
# | **Ventaja mecanica** | $\boxed{VM = \dfrac{F_{\text{salida}}}{F_{\text{entrada}}} = \dfrac{v_{\text{entrada}}}{v_{\text{salida}}}}$ | Consecuencia de la conservacion de potencia (caso ideal) |

# %% [markdown]
# ---
#
# ## 2. Tema 2 - Cinematica de Mecanismos
#
# Ecuaciones de cierre, Jacobiano y analisis de velocidades/aceleraciones.

# %% [markdown]
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Ecuacion de cierre (posicion)** | $\boxed{\sum_{i} l_i \, e^{j\theta_i} = 0}$ | Vector-loop: la suma de vectores en el bucle cerrado es cero |
# | **Componentes cartesianas** | $\sum l_i \cos\theta_i = 0$, $\;\sum l_i \sin\theta_i = 0$ | Separar parte real e imaginaria |
# | **Ecuacion de velocidad** | $\boxed{[J]\{\dot{\theta}\} = \{b\}}$ | Derivar cierre: $\sum l_i\,\dot{\theta}_i\,j\,e^{j\theta_i} = 0$ |
# | **Jacobiano de velocidad** | $[J]$ es la matriz de coeficientes de las incognitas $\dot{\theta}_j$ | Singularidad cuando $\det(J) = 0$ |
# | **Ecuacion de aceleracion** | $\boxed{[J]\{\ddot{\theta}\} = \{c\}}$ | $\{c\}$ incluye terminos centripetos: $-l_i\,\dot{\theta}_i^{\,2}\,e^{j\theta_i}$ |
# | **Velocidad relativa** | $\boxed{\vec{v}_P = \vec{v}_O + \vec{\omega} \times \overrightarrow{OP}}$ | $P$ y $O$ del mismo solido rigido |
# | **CIR (Centro Instantaneo de Rotacion)** | $\boxed{\vec{v}_P = \vec{\omega} \times \overrightarrow{IP}}$ | $I$: punto de velocidad nula; $v_P = \omega \cdot |IP|$ |
# | **Teorema de Kennedy** | 3 eslabones definen 3 CIR que estan alineados | Util para localizar CIR por interseccion |
# | **Numero de CIR** | $\boxed{n_{\text{CIR}} = \dfrac{N(N-1)}{2}}$ | $N$: numero de eslabones (incluido el fijo) |

# %% [markdown]
# ---
#
# ## 3. Apendice - Cinematica del Solido Rigido
#
# Fundamentos de movimiento de solido rigido: Chasles, Poisson, derivadas en referencia movil y composicion de movimientos.

# %% [markdown]
# ### 3.1 Teoremas fundamentales
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Teorema de Chasles** | Todo movimiento de SR es combinacion de traslacion + rotacion | En plano: traslacion + rotacion respecto a un eje $\perp$ al plano |
# | **Formulas de Poisson** | $\boxed{\dfrac{d\hat{e}_i}{dt} = \vec{\omega} \times \hat{e}_i}$ | $\hat{e}_i$: vectores unitarios solidarios al cuerpo |
# | **Derivada en ref. movil** | $\boxed{\left.\dfrac{d\vec{A}}{dt}\right|_{\text{fija}} = \left.\dfrac{d\vec{A}}{dt}\right|_{\text{movil}} + \vec{\omega} \times \vec{A}}$ | Relaciona derivadas en sistemas de referencia 1 (fija) y 2 (movil) |

# %% [markdown]
# ### 3.2 Campo de velocidades y aceleraciones
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Velocidad de un punto** | $\boxed{\vec{v}_P = \vec{v}_O + \vec{\omega} \times \overrightarrow{OP}}$ | $O$: punto de referencia del SR |
# | **Aceleracion de un punto** | $\boxed{\vec{a}_P = \vec{a}_O + \vec{\alpha} \times \overrightarrow{OP} + \vec{\omega} \times (\vec{\omega} \times \overrightarrow{OP})}$ | Ultimo termino = aceleracion centripeta $= -\omega^2\,\overrightarrow{OP}$ (en plano) |
# | **Aceleracion (plano)** | $\vec{a}_P = \vec{a}_O + \vec{\alpha} \times \overrightarrow{OP} - \omega^2\,\overrightarrow{OP}$ | Tangencial ($\alpha \times$) + centripeta ($-\omega^2$) |

# %% [markdown]
# ### 3.3 Composicion de movimientos
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Composicion de velocidades** | $\boxed{\vec{v}_{31} = \vec{v}_{32} + \vec{v}_{21}}$ | Movimiento de 3 respecto a 1 = mov. de 3 resp. 2 + mov. de 2 resp. 1 |
# | **Composicion de $\omega$** | $\boxed{\vec{\omega}_{31} = \vec{\omega}_{32} + \vec{\omega}_{21}}$ | Las velocidades angulares se suman vectorialmente |
# | **Composicion de aceleraciones** | $\boxed{\vec{a}_{31} = \vec{a}_{32} + \vec{a}_{21} + \vec{a}_{\text{Cor}}}$ | Aparece el termino de Coriolis |
# | **Aceleracion de Coriolis** | $\boxed{\vec{a}_{\text{Cor}} = 2\,\vec{\omega}_{21} \times \vec{v}_{32}}$ | $\vec{\omega}_{21}$: rotacion de la referencia 2 resp. 1; $\vec{v}_{32}$: vel. relativa en ref. 2 |
# | **Composicion de $\alpha$** | $\boxed{\vec{\alpha}_{31} = \vec{\alpha}_{32} + \vec{\alpha}_{21} + \vec{\omega}_{21} \times \vec{\omega}_{32}}$ | Ultimo termino solo si ambas $\omega$ no son paralelas (en plano = 0) |

# %% [markdown]
# ---
#
# ## 4. Tema 3 - Dinamica de Mecanismos
#
# Fuerzas de inercia (D'Alembert), balance de potencias, reacciones en pares y friccion.

# %% [markdown]
# ### 4.1 Fuerzas y momentos de inercia (D'Alembert)
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Fuerza de inercia** | $\boxed{\vec{F}_i = -m\,\vec{a}_G}$ | $G$: centro de masas del eslabon |
# | **Momento de inercia** | $\boxed{M_i = -I_G\,\alpha}$ | $I_G$: momento de inercia respecto a $G$ |
# | **Teorema de Steiner** | $\boxed{I_O = I_G + m\,d^2}$ | $d$: distancia de $G$ al eje $O$ |
# | **Principio de D'Alembert** | $\sum \vec{F}_{\text{ext}} + \vec{F}_i = 0$, $\;\sum M_{\text{ext}} + M_i = 0$ | Convierte dinamica en equilibrio estatico equivalente |

# %% [markdown]
# ### 4.2 Balance de potencias y energia
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Balance de potencias** | $\boxed{P_{\text{mot}} + P_{\text{grav}} + P_{\text{in}} + P_{\text{fric}} = 0}$ | Todas las potencias del sistema suman cero |
# | **Potencia motora** | $P_{\text{mot}} = M_{\text{mot}} \cdot \omega$ o $P = \vec{F} \cdot \vec{v}$ | Par motor por velocidad angular |
# | **Potencia gravitatoria** | $P_{\text{grav}} = -m\,g\,\dot{y}_G$ | Negativa si sube el CdG |
# | **Potencia de inercia** | $P_{\text{in}} = -m\,\vec{a}_G \cdot \vec{v}_G - I_G\,\alpha\,\omega$ | Potencia de las fuerzas/momentos de inercia |
# | **Teorema de la energia cinetica** | $\boxed{W_{\text{ext}} = \Delta T = T_f - T_i}$ | $T = \frac{1}{2}m v_G^2 + \frac{1}{2}I_G\omega^2$ |
# | **Energia cinetica (rotacion pura)** | $T = \frac{1}{2}I_O\,\omega^2$ | Si el eslabon rota respecto a $O$ fijo |

# %% [markdown]
# ### 4.3 Reacciones en pares cinematicos
#
# | Tipo de par | Reacciones | Descripcion |
# |-------------|------------|-------------|
# | **Rotacion (R)** | $R_x,\; R_y$ | 2 componentes de fuerza (perpendiculares al eje) |
# | **Prismático (P)** | $N,\; M$ | Fuerza normal + momento |
# | **Leva (superior)** | $N$ | Solo fuerza normal al contacto |
# | **Rodillo sobre superficie (RSD)** | $N + T$ | Normal + tangencial (si hay friccion $T = \mu N$) |
# | **Empotramiento** | $R_x,\; R_y,\; M$ | 2 fuerzas + 1 momento (0 GDL en plano) |

# %% [markdown]
# ### 4.4 Friccion
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Coulomb (deslizamiento)** | $\boxed{F = \mu\,N}$ | $\mu$: coeficiente de friccion cinematica |
# | **Direccion** | $\vec{F}_{\text{fric}}$ opuesta al movimiento relativo | En un par R: par de friccion $M_f = \mu\,|R|\,r$ |
# | **Potencia de friccion** | $\boxed{P_{\text{fric}} = -\mu\,N\,|v_{\text{rel}}| \leq 0}$ | Siempre negativa (disipativa) |
# | **Friccion en par R** | $M_f = \mu \cdot |\vec{R}| \cdot r_{\text{eje}}$ | $r_{\text{eje}}$: radio del eje/pasador |

# %% [markdown]
# ---
#
# ## 5. Tema 3B - Vibraciones Mecanicas
#
# Sistemas de 1 GDL: vibraciones libres, amortiguadas y forzadas.

# %% [markdown]
# ### 5.1 Parametros fundamentales
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Frecuencia natural** | $\boxed{\omega_n = \sqrt{\dfrac{k}{m}}}$ | $k$: rigidez, $m$: masa |
# | **Coef. amortiguamiento** | $\boxed{\xi = \dfrac{c}{2m\,\omega_n} = \dfrac{c}{c_{\text{crit}}}}$ | Adimensional: $\xi < 1$ subamortiguado, $\xi = 1$ critico, $\xi > 1$ sobreamortiguado |
# | **Amortiguamiento critico** | $\boxed{c_{\text{crit}} = 2\sqrt{k\,m} = 2m\,\omega_n}$ | Frontera entre oscilatorio y no oscilatorio |
# | **Frecuencia amortiguada** | $\boxed{\omega_d = \omega_n\sqrt{1 - \xi^2}}$ | Solo para $\xi < 1$ (subamortiguado) |
# | **Periodo** | $T_n = \dfrac{2\pi}{\omega_n}$, $\;T_d = \dfrac{2\pi}{\omega_d}$ | $T_d > T_n$ siempre |

# %% [markdown]
# ### 5.2 Vibracion libre amortiguada ($\xi < 1$)
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Ecuacion de movimiento** | $m\ddot{x} + c\dot{x} + kx = 0$ | Dividiendo por $m$: $\ddot{x} + 2\xi\omega_n\dot{x} + \omega_n^2 x = 0$ |
# | **Respuesta libre** | $\boxed{x(t) = e^{-\xi\omega_n t}\left(C_1\cos(\omega_d t) + C_2\sin(\omega_d t)\right)}$ | Envolvente exponencial decreciente |
# | **Condiciones iniciales** | $\boxed{C_1 = x_0}$, $\;\boxed{C_2 = \dfrac{\dot{x}_0 + \xi\omega_n x_0}{\omega_d}}$ | $x_0 = x(0)$, $\dot{x}_0 = \dot{x}(0)$ |
# | **Decremento logaritmico** | $\boxed{\delta = \ln\!\left(\dfrac{x(t)}{x(t+T_d)}\right) = \dfrac{2\pi\xi}{\sqrt{1-\xi^2}}}$ | Medir picos consecutivos para obtener $\xi$ |
# | **$\xi$ desde $\delta$** | $\boxed{\xi = \dfrac{\delta}{\sqrt{4\pi^2 + \delta^2}}}$ | Invertir la formula del decremento |

# %% [markdown]
# ### 5.3 Vibracion forzada armonica
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Ecuacion de movimiento** | $m\ddot{x} + c\dot{x} + kx = F_0\cos(\Omega t)$ | $\Omega$: frecuencia de excitacion |
# | **Relacion de frecuencias** | $r = \dfrac{\Omega}{\omega_n}$ | $r = 1$: resonancia |
# | **Amplitud estacionaria** | $\boxed{X = \dfrac{F_0/k}{\sqrt{(1-r^2)^2 + (2\xi r)^2}}}$ | $F_0/k$: deflexion estatica |
# | **Factor de amplificacion** | $\boxed{H(r) = \dfrac{1}{\sqrt{(1-r^2)^2 + (2\xi r)^2}}}$ | Maximo cerca de $r = 1$ para $\xi$ pequeno |
# | **Desfase** | $\boxed{\phi = \arctan\!\left(\dfrac{2\xi r}{1-r^2}\right)}$ | $\phi \to 90°$ en resonancia |
# | **Transmisibilidad** | $\boxed{TR = \dfrac{F_{\text{trans}}}{F_0} = \sqrt{\dfrac{1 + (2\xi r)^2}{(1-r^2)^2 + (2\xi r)^2}}}$ | Fuerza transmitida a la base |
# | **Aislamiento eficaz** | $TR < 1$ cuando $r > \sqrt{2}$ | Independiente de $\xi$ para $r = \sqrt{2}$ |

# %% [markdown]
# ### 5.4 Metodo de Lagrange
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Ecuacion de Lagrange** | $\boxed{\dfrac{d}{dt}\!\left(\dfrac{\partial T}{\partial \dot{q}_i}\right) - \dfrac{\partial T}{\partial q_i} + \dfrac{\partial V}{\partial q_i} + \dfrac{\partial D}{\partial \dot{q}_i} = Q_i}$ | $T$: E. cinetica, $V$: E. potencial, $D$: funcion de disipacion de Rayleigh |
# | **Funcion de Rayleigh** | $D = \frac{1}{2}c\,\dot{q}^2$ | $\frac{\partial D}{\partial \dot{q}} = c\,\dot{q}$ |
# | **Linealizacion** | Desarrollar $T$ y $V$ alrededor del equilibrio; $\sin\theta \approx \theta$, $\cos\theta \approx 1$ | Para obtener $\omega_n$ de la ecuacion linealizada |

# %% [markdown]
# ---
#
# ## 6. Tema 4 - Sintesis de Mecanismos
#
# Sintesis estructural, ecuacion de Freudenstein y espaciado de Chebyshev.

# %% [markdown]
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Sintesis estructural (suma de tipos)** | $\boxed{N - (G + 3) + 2t + 6q + \cdots = T + 2Q + 3P + \cdots}$ | Eslabones $N$, GDL $G$; $t,q$: pares binarios/ternarios; $T,Q,P$: eslabones ternarios, cuaternarios, pentagonales |
# | **Freudenstein (4 barras)** | $\boxed{R_1\cos\psi - R_2\cos\phi + R_3 = \cos(\phi - \psi)}$ | Relaciona angulo de entrada $\phi$ con angulo de salida $\psi$ |
# | **Coeficientes de Freudenstein** | $\boxed{R_1 = \dfrac{d}{c}, \quad R_2 = \dfrac{d}{a}, \quad R_3 = \dfrac{a^2 - b^2 + c^2 + d^2}{2ac}}$ | $a$: manivela, $b$: biela, $c$: balancin, $d$: fijo |
# | **Sintesis de 3 posiciones** | 3 ecuaciones de Freudenstein con $(\phi_i, \psi_i)$ para $i=1,2,3$ | Sistema lineal en $R_1, R_2, R_3 \Rightarrow$ obtener $a, b, c, d$ |
# | **Espaciado de Chebyshev** | $\boxed{x_j = \dfrac{1}{2}(x_0 + x_N) - \dfrac{1}{2}(x_N - x_0)\cos\!\left(\dfrac{2j - 1}{2N}\,\pi\right)}$ | $j = 1, \ldots, N$. Minimiza el error maximo (minimax) |
# | **Precision points** | Puntos donde la funcion generada coincide exactamente con la deseada | $N$ puntos de precision $\Rightarrow$ $N$ ecuaciones |

# %% [markdown]
# ---
#
# ## 7. Tema 5 - Engranajes
#
# Geometria de dientes, ley de engranamiento, perfil evolvente y trenes de engranajes.

# %% [markdown]
# ### 7.1 Geometria del diente (engranaje recto)
#
# | Parametro | Formula | Notas |
# |-----------|---------|-------|
# | **Modulo** | $\boxed{m = \dfrac{d}{Z}}$ | $d$: diametro primitivo, $Z$: numero de dientes |
# | **Paso circular** | $\boxed{p = \pi\,m}$ | Distancia entre dientes consecutivos (sobre primitiva) |
# | **Adendo (cabeza)** | $\boxed{h_a = m}$ | Altura del diente por encima de la primitiva |
# | **Dedendo (pie)** | $\boxed{h_f = 1{,}25\,m}$ | Altura del diente por debajo de la primitiva |
# | **Diametro de cabeza** | $\boxed{d_a = m(Z + 2)}$ | $d_a = d + 2h_a$ |
# | **Diametro de pie** | $\boxed{d_f = m(Z - 2{,}5)}$ | $d_f = d - 2h_f$ |
# | **Diametro base** | $\boxed{d_b = d\cos\alpha}$ | $\alpha$: angulo de presion (tipicamente $20°$) |
# | **Distancia entre centros** | $\boxed{a_c = \dfrac{m(Z_1 + Z_2)}{2}}$ | Para engranajes exteriores sin correccion |

# %% [markdown]
# ### 7.2 Ley de engranamiento y relacion de transmision
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Relacion de transmision** | $\boxed{i = \dfrac{\omega_1}{\omega_2} = \dfrac{Z_2}{Z_1}}$ | $i > 1$: reduccion; $i < 1$: multiplicacion |
# | **Ruedas de friccion** | $\boxed{\eta = -\dfrac{R_2}{R_1}}$ | Signo negativo: sentidos opuestos (contacto exterior) |
# | **Ley fundamental** | $\boxed{\dfrac{\omega_2}{\omega_1} = -\dfrac{d_1}{d_2} = \text{cte}}$ | La normal comun en el contacto pasa siempre por el punto primitivo |
# | **Perfiles conjugados** | $\dfrac{\omega_i}{\omega_j} = -\dfrac{d_j}{d_i} = \text{constante}$ | Condicion para transmision uniforme |

# %% [markdown]
# ### 7.3 Perfil evolvente (involuta)
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Parametrizacion** | $\boxed{\begin{cases} x = r_b(\cos t + t\sin t) \\ y = r_b(\sin t - t\cos t) \end{cases}}$ | $r_b$: radio base, $t$: parametro (angulo de desenrollamiento) |
# | **Funcion evolvente** | $\boxed{\text{inv}(\alpha) = \tan\alpha - \alpha}$ | Util para calculo de espesores y correcciones |
# | **Angulo de presion** | $\cos\alpha = \dfrac{r_b}{r}$ | Varia con el radio; $\alpha$ en primitiva es el nominal ($20°$) |

# %% [markdown]
# ### 7.4 Trenes de engranajes
#
# | Concepto | Formula | Notas |
# |----------|---------|-------|
# | **Tren ordinario** | $\boxed{i_{\text{total}} = \prod_k i_k = \prod_k \dfrac{Z_{\text{conducido},k}}{Z_{\text{conductor},k}}}$ | Signo: $(-)$ por cada contacto exterior |
# | **Tren epicicloidal (Willis)** | $\boxed{\dfrac{\omega_i - \omega_{\text{brazo}}}{\omega_j - \omega_{\text{brazo}}} = \pm\dfrac{Z_j}{Z_i}}$ | Inversion cinematica: restar $\omega_{\text{brazo}}$ a todo |
# | **Razon fundamental** | $i_0 = \dfrac{\omega_{\text{sol}} - \omega_{\text{brazo}}}{\omega_{\text{corona}} - \omega_{\text{brazo}}}$ | $i_0 = -Z_{\text{corona}}/Z_{\text{sol}}$ (tren simple sol-planeta-corona) |
# | **Condicion geometrica** | $Z_{\text{corona}} = Z_{\text{sol}} + 2\,Z_{\text{planeta}}$ | Para engranaje interior (corona) con contacto correcto |

# %% [markdown]
# ---
#
# ## 8. Resumen rapido: que formula usar en cada tipo de problema
#
# Guia de seleccion de formulas segun el tipo de ejercicio del examen.

# %% [markdown]
# | Tipo de problema | Formulas clave | Seccion |
# |------------------|----------------|---------|
# | **Calcular GDL de un mecanismo** | Gruebler: $G = 3(N-1)-2g-h$; identificar pares N-arios | Sec. 1 |
# | **Verificar si hay manivela completa** | Grashof: $s+l \leq p+q$ | Sec. 1 |
# | **Posiciones de un mecanismo** | Ecuacion de cierre: $\sum l_i e^{j\theta_i} = 0$ | Sec. 2 |
# | **Velocidades (metodo analitico)** | $[J]\{\dot{\theta}\} = \{b\}$ | Sec. 2 |
# | **Velocidades (metodo grafico)** | CIR + $v_P = \omega \cdot |IP|$ + Kennedy | Sec. 2 |
# | **Aceleraciones** | $[J]\{\ddot{\theta}\} = \{c\}$ con centripetos; $\vec{a}_P = \vec{a}_O + \alpha \times \overrightarrow{OP} - \omega^2 \overrightarrow{OP}$ | Sec. 2, 3 |
# | **Mecanismo con corredera/leva** | Composicion + Coriolis: $\vec{a}_{\text{Cor}} = 2\omega \times v_{\text{rel}}$ | Sec. 3 |
# | **Par motor necesario** | Balance de potencias: $P_{\text{mot}} + P_{\text{grav}} + P_{\text{in}} + P_{\text{fric}} = 0$ | Sec. 4 |
# | **Reacciones en pares** | D'Alembert: $\vec{F}_i = -m\vec{a}_G$, $M_i = -I_G\alpha$; equilibrio eslabon a eslabon | Sec. 4 |
# | **Efecto de la friccion** | Coulomb $F = \mu N$; par de friccion en eje $M_f = \mu|R|r$ | Sec. 4 |
# | **Frecuencia natural / amortiguamiento** | $\omega_n = \sqrt{k/m}$, $\xi = c/(2m\omega_n)$ | Sec. 5 |
# | **Respuesta libre amortiguada** | $x(t) = e^{-\xi\omega_n t}(C_1\cos\omega_d t + C_2\sin\omega_d t)$ | Sec. 5 |
# | **Identificar $\xi$ experimentalmente** | Decremento logaritmico: $\delta = 2\pi\xi/\sqrt{1-\xi^2}$ | Sec. 5 |
# | **Amplitud en forzada** | $X = \frac{F_0/k}{\sqrt{(1-r^2)^2+(2\xi r)^2}}$ | Sec. 5 |
# | **Obtener ecuacion de movimiento** | Lagrange: $\frac{d}{dt}(\partial T/\partial \dot{q}) - \partial T/\partial q + \partial V/\partial q = Q$ | Sec. 5 |
# | **Disenar un 4 barras** | Freudenstein: $R_1\cos\psi - R_2\cos\phi + R_3 = \cos(\phi-\psi)$ | Sec. 6 |
# | **Relacion de transmision (engranajes)** | $i = Z_2/Z_1$; tren: $i_{\text{total}} = \prod Z_{\text{cond}}/Z_{\text{ctor}}$ | Sec. 7 |
# | **Tren epicicloidal** | Willis: $(\omega_i - \omega_{\text{brazo}})/(\omega_j - \omega_{\text{brazo}}) = \pm Z_j/Z_i$ | Sec. 7 |
