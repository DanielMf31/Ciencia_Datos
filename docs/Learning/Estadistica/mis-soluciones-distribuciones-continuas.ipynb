# %% [markdown]
# # Mis Soluciones: Distribuciones Continuas
#
# Ejercicios resueltos de distribuciones de probabilidad continuas: Normal, Exponencial, t-Student, Chi-cuadrado y F de Snedecor.
#
# Instrucciones: Resuelve cada ejercicio en la celda de codigo vacia.

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Paleta de colores
C_PRIMARY = '#3498db'
C_DANGER = '#e74c3c'
C_SUCCESS = '#2ecc71'
C_DARK = '#2c3e50'
C_ORANGE = '#f39c12'

# Estilo global
plt.rcParams.update({
    'figure.figsize': (10, 5),
    'axes.spines.top': False,
    'axes.spines.right': False,
    'font.size': 12,
    'axes.titlesize': 14,
    'axes.labelsize': 12,
})

# %% [markdown]
# ## Formulas de distribuciones continuas
#
# ---
#
# ### 1. Normal — $X \sim N(\mu, \sigma)$
#
# **PDF (funcion de densidad de probabilidad):**
#
# $$f(x) = \frac{1}{\sigma\sqrt{2\pi}} \, e^{-\frac{(x-\mu)^2}{2\sigma^2}}, \quad x \in (-\infty, \infty)$$
#
# - $\mu$: media (centro de la campana)
# - $\sigma$: desviacion estandar (controla el ancho de la campana)
# - $\sigma^2$: varianza
# - $e$: constante de Euler (aprox. 2.71828)
# - $\pi$: constante pi (aprox. 3.14159)
#
# **Esperanza:** $E[X] = \mu$
#
# **Varianza:** $\text{Var}(X) = \sigma^2$
#
# ---
#
# ### 2. Exponencial — $X \sim \text{Exp}(\lambda)$
#
# **PDF:**
#
# $$f(x) = \lambda \, e^{-\lambda x}, \quad x \geq 0$$
#
# - $\lambda$: tasa del evento (numero medio de eventos por unidad de tiempo)
# - $1/\lambda$: tiempo medio entre eventos
#
# **Esperanza:** $E[X] = \frac{1}{\lambda}$
#
# **Varianza:** $\text{Var}(X) = \frac{1}{\lambda^2}$
#
# ---
#
# ### 3. Gamma — $X \sim \text{Gamma}(\alpha, \beta)$
#
# **PDF:**
#
# $$f(x) = \frac{\beta^\alpha}{\Gamma(\alpha)} \, x^{\alpha-1} \, e^{-\beta x}, \quad x > 0$$
#
# - $\alpha$ (shape): parametro de forma, indica el numero de eventos acumulados
# - $\beta$ (rate): parametro de tasa, inverso de la escala
# - $\Gamma(\alpha)$: funcion Gamma, generalizacion del factorial; $\Gamma(n) = (n-1)!$ para enteros positivos
#
# **Esperanza:** $E[X] = \frac{\alpha}{\beta}$
#
# **Varianza:** $\text{Var}(X) = \frac{\alpha}{\beta^2}$
#
# ---
#
# ### 4. Beta — $X \sim \text{Beta}(\alpha, \beta)$
#
# **PDF:**
#
# $$f(x) = \frac{x^{\alpha-1}(1-x)^{\beta-1}}{B(\alpha, \beta)}, \quad x \in [0, 1]$$
#
# - $\alpha$: parametro de forma asociado a exitos
# - $\beta$: parametro de forma asociado a fracasos
# - $B(\alpha, \beta)$: funcion Beta, $B(\alpha, \beta) = \frac{\Gamma(\alpha)\Gamma(\beta)}{\Gamma(\alpha+\beta)}$
#
# **Esperanza:** $E[X] = \frac{\alpha}{\alpha + \beta}$
#
# **Varianza:** $\text{Var}(X) = \frac{\alpha\beta}{(\alpha+\beta)^2(\alpha+\beta+1)}$
#
# ---
#
# ### 5. t-Student — $T \sim t(\nu)$
#
# **PDF:**
#
# $$f(t) = \frac{\Gamma\left(\frac{\nu+1}{2}\right)}{\sqrt{\nu\pi}\;\Gamma\left(\frac{\nu}{2}\right)} \left(1 + \frac{t^2}{\nu}\right)^{-\frac{\nu+1}{2}}, \quad t \in (-\infty, \infty)$$
#
# - $\nu$ (nu): grados de libertad, tipicamente $n - 1$ donde $n$ es el tamano muestral
# - $\Gamma$: funcion Gamma
#
# **Esperanza:** $E[T] = 0$ (para $\nu > 1$)
#
# **Varianza:** $\text{Var}(T) = \frac{\nu}{\nu - 2}$ (para $\nu > 2$)
#
# ---
#
# ### 6. Chi-cuadrado — $X \sim \chi^2(k)$
#
# **PDF:**
#
# $$f(x) = \frac{1}{2^{k/2}\,\Gamma(k/2)} \, x^{k/2 - 1} \, e^{-x/2}, \quad x > 0$$
#
# - $k$: grados de libertad (numero de normales estandar al cuadrado sumadas)
# - $\Gamma$: funcion Gamma
#
# **Esperanza:** $E[X] = k$
#
# **Varianza:** $\text{Var}(X) = 2k$
#
# ---
#
# ### 7. F de Snedecor — $X \sim F(d_1, d_2)$
#
# **PDF:**
#
# $$f(x) = \frac{\sqrt{\frac{(d_1 x)^{d_1} \cdot d_2^{d_2}}{(d_1 x + d_2)^{d_1+d_2}}}}{x\,B\left(\frac{d_1}{2}, \frac{d_2}{2}\right)}, \quad x > 0$$
#
# - $d_1$: grados de libertad del numerador
# - $d_2$: grados de libertad del denominador
# - $B$: funcion Beta
#
# **Esperanza:** $E[X] = \frac{d_2}{d_2 - 2}$ (para $d_2 > 2$)
#
# **Varianza:** $\text{Var}(X) = \frac{2\,d_2^2\,(d_1 + d_2 - 2)}{d_1\,(d_2-2)^2\,(d_2-4)}$ (para $d_2 > 4$)
#
# ---
#
# ### 8. Uniforme continua — $X \sim U(a, b)$
#
# **PDF:**
#
# $$f(x) = \frac{1}{b - a}, \quad x \in [a, b]$$
#
# - $a$: limite inferior del intervalo
# - $b$: limite superior del intervalo
# - La densidad es constante en todo el intervalo
#
# **Esperanza:** $E[X] = \frac{a + b}{2}$
#
# **Varianza:** $\text{Var}(X) = \frac{(b - a)^2}{12}$
#
# ---
#
# ### 9. Log-normal — $X \sim \text{LogN}(\mu, \sigma)$
#
# **PDF:**
#
# $$f(x) = \frac{1}{x\,\sigma\sqrt{2\pi}} \, e^{-\frac{(\ln x - \mu)^2}{2\sigma^2}}, \quad x > 0$$
#
# - $\mu$: media del logaritmo natural de $X$ (no la media de $X$ en si)
# - $\sigma$: desviacion estandar del logaritmo natural de $X$
# - $\ln x$: logaritmo natural de $x$
# - Si $Y \sim N(\mu, \sigma)$, entonces $X = e^Y \sim \text{LogN}(\mu, \sigma)$
#
# **Esperanza:** $E[X] = e^{\mu + \sigma^2/2}$
#
# **Varianza:** $\text{Var}(X) = \left(e^{\sigma^2} - 1\right) e^{2\mu + \sigma^2}$

# %% [markdown]
# **Ejercicio 1:** Las alturas de una poblacion siguen una distribucion Normal con media 170 cm y desviacion estandar 10 cm. Cual es la probabilidad de que una persona elegida al azar mida entre 160 y 180 cm?

# %%
# Tu solucion para el Ejercicio 1
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 2:** En un examen, las calificaciones siguen una distribucion Normal con media 65 y desviacion estandar 12. Que nota necesitas para estar en el top 5% de la clase?

# %%
# Tu solucion para el Ejercicio 2
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 3:** Un componente electronico tiene una vida media de 500 horas (lambda = 1/500). Cual es la probabilidad de que dure mas de 600 horas? Y de que dure entre 400 y 600 horas?

# %%
# Tu solucion para el Ejercicio 3
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 4:** Se toman 15 muestras de un proceso y se obtiene una media muestral de 72 y una desviacion estandar muestral de 8. Construir un intervalo de confianza al 95% para la media poblacional.

# %%
# Tu solucion para el Ejercicio 4
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 5:** Una muestra de n=20 observaciones tiene una varianza muestral de s^2=25. Testear la hipotesis de que la varianza poblacional es sigma^2=20 con un nivel de significacion alfa=0.05 (test bilateral).

# %%
# Tu solucion para el Ejercicio 5
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 6:** Calcular los valores criticos z tales que P(-z < Z < z) = 0.90, 0.95 y 0.99 para la distribucion Normal estandar. Construir una tabla de valores criticos.

# %%
# Tu solucion para el Ejercicio 6
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 7:** Se quiere comparar la variabilidad de dos procesos de produccion. El grupo 1 tiene n1=25 muestras con s1^2=15, y el grupo 2 tiene n2=30 muestras con s2^2=10. Realizar un F-test para determinar si las varianzas son significativamente diferentes (alfa=0.05).

# %%
# Tu solucion para el Ejercicio 7
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 8:** Para cada distribucion continua estudiada (Normal, Exponencial, t-Student, Chi-cuadrado, F de Snedecor), graficar la PDF con diferentes parametros en un grid 2x4. Construir una tabla resumen con E[X] y Var(X).

# %%
# Tu solucion para el Ejercicio 8
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 9:** El coeficiente intelectual (IQ) de una poblacion sigue una distribucion Normal con media 100 y desviacion estandar 15, es decir, $X \sim N(100, 15)$. Que porcentaje de la poblacion tiene un IQ entre 85 y 115? Y que porcentaje tiene un IQ por encima de 130?

# %%
# Tu solucion para el Ejercicio 9
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 10:** El tiempo entre llamadas en un centro de atencion sigue una distribucion Exponencial con tasa $\lambda = 3$ llamadas por minuto, es decir, $X \sim \text{Exp}(\lambda=3)$. Cual es la probabilidad de esperar mas de 1 minuto entre dos llamadas consecutivas?

# %%
# Tu solucion para el Ejercicio 10
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 11:** El tiempo necesario para que ocurran 5 eventos, donde cada evento ocurre con una tasa de 2 por hora, sigue una distribucion Gamma con parametros $\alpha=5$ (forma) y $\beta=2$ (tasa), es decir, $T \sim \text{Gamma}(5, 2)$. Calcular la esperanza $E[T]$ y la probabilidad $P(T > 4)$.

# %%
# Tu solucion para el Ejercicio 11
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 12:** La proporcion de exitos en un experimento sigue una distribucion Beta con parametros $\alpha=2$ y $\beta=5$, es decir, $X \sim \text{Beta}(2, 5)$. Calcular la esperanza $E[X]$, la moda, y graficar la distribucion.

# %%
# Tu solucion para el Ejercicio 12
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 13:** La suma de los cuadrados de 10 variables normales estandar independientes sigue una distribucion Chi-cuadrado con 10 grados de libertad, es decir, $Y = \sum_{i=1}^{10} Z_i^2 \sim \chi^2(10)$ donde cada $Z_i \sim N(0,1)$. Calcular $P(\chi^2 > 18.31)$.

# %%
# Tu solucion para el Ejercicio 13
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 14:** Se tiene una muestra de $n=8$ observaciones con media muestral $\bar{x}=25$ y desviacion estandar muestral $s=4$. Bajo el supuesto de normalidad, el estadistico $t = \frac{\bar{x} - \mu_0}{s/\sqrt{n}}$ sigue una distribucion t-Student con $\nu = n-1 = 7$ grados de libertad. Calcular la probabilidad de que $t > 2.0$.

# %%
# Tu solucion para el Ejercicio 14
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 15:** Los salarios anuales de una empresa siguen una distribucion Log-normal con parametros $\mu=10$ y $\sigma=0.5$, es decir, $X \sim \text{LogN}(10, 0.5)$, donde $\mu$ y $\sigma$ son la media y desviacion estandar del logaritmo natural de los salarios. Calcular la mediana, la media, y la probabilidad de que un salario supere los 30000.

# %%
# Tu solucion para el Ejercicio 15
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 16:** El tiempo de espera de un autobus sigue una distribucion Uniforme continua entre 0 y 10 minutos, es decir, $X \sim U(0, 10)$. Calcular la probabilidad de esperar entre 3 y 7 minutos, y la esperanza $E[X]$.

# %%
# Tu solucion para el Ejercicio 16
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 17:** La regla 68-95-99.7 establece que para una distribucion Normal, aproximadamente el 68% de los datos caen dentro de 1 desviacion estandar de la media, el 95% dentro de 2, y el 99.7% dentro de 3. Verificar esta regla mediante simulacion de 100000 muestras de $Z \sim N(0,1)$.

# %%
# Tu solucion para el Ejercicio 17
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 18:** La distribucion Exponencial tiene la propiedad de falta de memoria (memoryless): $P(X > s + t \mid X > s) = P(X > t)$. Demostrar esta propiedad mediante calculo analitico y verificarla con una simulacion para $X \sim \text{Exp}(\lambda=2)$, con $s=1$ y $t=0.5$.

# %%
# Tu solucion para el Ejercicio 18
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 19:** La distribucion F de Snedecor se define como el cociente de dos variables Chi-cuadrado independientes, cada una dividida por sus grados de libertad. Si $U \sim \chi^2(d_1)$ y $V \sim \chi^2(d_2)$ son independientes, entonces $F = \frac{U/d_1}{V/d_2} \sim F(d_1, d_2)$. Simular este cociente con $d_1=5$ y $d_2=10$, y comparar el histograma con la densidad F teorica.

# %%
# Tu solucion para el Ejercicio 19
# Escribe tu codigo aqui

# %% [markdown]
# **Ejercicio 20:** Crear una galeria visual que muestre las 9 distribuciones continuas estudiadas (Normal, Exponencial, Gamma, Beta, t-Student, Chi-cuadrado, F de Snedecor, Uniforme continua, Log-normal) en un grid 3x3, cada una con diferentes combinaciones de parametros para observar como cambian sus formas.

# %%
# Tu solucion para el Ejercicio 20
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 21: Mezcla de distribuciones normales
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Modelo de mezcla bimodal:**
#
# Considerar la mezcla $f(x) = 0.4 \cdot \mathcal{N}(20, 3^2) + 0.6 \cdot \mathcal{N}(40, 5^2)$.
#
# - La esperanza es $E[X] = 0.4 \cdot 20 + 0.6 \cdot 40 = 32$.
# - Graficar la PDF de la mezcla y verificar la bimodalidad.
# - Simular 10000 muestras y comparar el histograma con la PDF teorica.
# - Calcular la varianza total usando la ley de la varianza total.
#
# </div>

# %%
# Tu solucion para el Ejercicio 21
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 22: Distribucion Weibull y probabilidad de supervivencia
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Weibull en analisis de fiabilidad:**
#
# Para $X \sim \text{Weibull}(k=2, \lambda=1000)$:
#
# - Calcular $P(X > 800)$, la probabilidad de sobrevivir mas de 800 horas.
# - Graficar la funcion de supervivencia $S(t) = 1 - F(t)$.
# - Graficar la funcion de riesgo $h(t) = f(t)/S(t)$.
# - Con $k=2$ el riesgo es creciente (desgaste). Comparar con $k=1$ (riesgo constante, exponencial).
#
# </div>

# %%
# Tu solucion para el Ejercicio 22
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 23: Distribucion de Pareto y colas pesadas
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Pareto y eventos extremos:**
#
# Para $X \sim \text{Pareto}(\alpha=2, x_m=10000)$:
#
# - Calcular $P(X > 100000)$, la probabilidad de un valor 10 veces mayor al minimo.
# - Graficar la PDF en escala log-log para observar la ley de potencia.
# - Comparar la cola con una distribucion exponencial.
# - La media es $E[X] = \frac{\alpha \cdot x_m}{\alpha - 1} = 20000$.
#
# </div>

# %%
# Tu solucion para el Ejercicio 23
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 24: Transformacion lognormal via Jacobiano
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Derivacion de la PDF lognormal:**
#
# Si $X \sim \mathcal{N}(0,1)$ y $Y = e^X$, entonces $Y$ sigue una distribucion lognormal.
#
# - Usar el metodo del Jacobiano: $f_Y(y) = f_X(g^{-1}(y)) \cdot |dg^{-1}/dy|$.
# - Con $g^{-1}(y) = \ln(y)$ y $|dg^{-1}/dy| = 1/y$.
# - Verificar que $f_Y(y) = \frac{1}{y\sqrt{2\pi}} e^{-(\ln y)^2/2}$.
# - Comparar simulacion con la PDF derivada.
#
# </div>

# %%
# Tu solucion para el Ejercicio 24
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 25: Coordenadas polares y Jacobiano bivariado
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Transformacion a coordenadas polares:**
#
# Si $X, Y \sim \mathcal{N}(0,1)$ independientes, transformar a $(R, \Theta)$ con $R = \sqrt{X^2+Y^2}$, $\Theta = \arctan(Y/X)$.
#
# - El Jacobiano de la transformacion inversa es $|J| = r$.
# - $R$ sigue una distribucion Rayleigh y $\Theta \sim \text{Uniform}(0, 2\pi)$.
# - $R$ y $\Theta$ son independientes.
# - Verificar con simulacion.
#
# </div>

# %%
# Tu solucion para el Ejercicio 25
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 26: Distribucion de Cauchy y colas pesadas
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Cauchy: la distribucion sin media:**
#
# Si $Z_1, Z_2 \sim \mathcal{N}(0,1)$ independientes, entonces $C = Z_1/Z_2 \sim \text{Cauchy}(0,1)$.
#
# - $E[X]$ no existe (la integral no converge).
# - Demostrar con simulacion que la media muestral no converge.
# - Comparar las colas de Cauchy con las de la normal estandar.
# - La mediana y la moda si existen y son iguales a 0.
#
# </div>

# %%
# Tu solucion para el Ejercicio 26
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 27: QQ-plot para evaluar normalidad
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Diagnostico grafico de normalidad:**
#
# - Generar datos de $\mathcal{N}(5,2)$ y de $\text{Exp}(1)$.
# - Construir QQ-plots contra la distribucion normal teorica.
# - Si los datos son normales, los puntos caen sobre la diagonal.
# - Desviaciones sistematicas indican asimetria o colas pesadas/ligeras.
#
# </div>

# %%
# Tu solucion para el Ejercicio 27
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 28: Test de Shapiro-Wilk para normalidad
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Test formal de normalidad:**
#
# - Aplicar `scipy.stats.shapiro` a datos normales y no normales.
# - $H_0$: los datos provienen de una distribucion normal.
# - Si p-valor < 0.05, se rechaza $H_0$ (datos no normales).
# - Comparar el poder del test con diferentes distribuciones alternativas.
#
# </div>

# %%
# Tu solucion para el Ejercicio 28
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 29: Test de Kolmogorov-Smirnov
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Comparar CDF empirica vs teorica:**
#
# - Generar datos de $\mathcal{N}(0,1)$ y aplicar el test KS contra $\mathcal{N}(0,1)$.
# - El estadistico $D_n = \sup_x |F_n(x) - F(x)|$.
# - Visualizar la CDF empirica y la teorica, resaltando la maxima diferencia.
# - Repetir con datos de una distribucion diferente.
#
# </div>

# %%
# Tu solucion para el Ejercicio 29
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 30: Estimacion de densidad por kernel (KDE)
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Kernel gaussiano y efecto del bandwidth:**
#
# - Generar datos de una mezcla bimodal.
# - Aplicar KDE con kernel gaussiano y diferentes valores de bandwidth.
# - Bandwidth pequeno: sobreajuste (mucho ruido).
# - Bandwidth grande: subajuste (pierde estructura).
# - Usar `scipy.stats.gaussian_kde` y variar `bw_method`.
#
# </div>

# %%
# Tu solucion para el Ejercicio 30
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 31: Distribucion del maximo de n uniformes
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Estadistico de orden maximo:**
#
# Si $X_1, \ldots, X_n \sim U(0,1)$ independientes, el maximo $X_{(n)}$ tiene CDF:
#
# $$F_{X_{(n)}}(x) = [F(x)]^n = x^n, \quad 0 \leq x \leq 1$$
#
# - Derivar la PDF: $f_{X_{(n)}}(x) = n x^{n-1}$.
# - Para $n=5$, graficar y verificar con simulacion.
# - Calcular $E[X_{(n)}] = n/(n+1)$.
#
# </div>

# %%
# Tu solucion para el Ejercicio 31
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 32: Distribucion del rango de n uniformes
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Rango muestral $R = X_{(n)} - X_{(1)}$:**
#
# Para $n$ variables $U(0,1)$ independientes, el rango $R = \max - \min$ tiene:
#
# - PDF: $f_R(r) = n(n-1) r^{n-2} (1-r)$, para $0 \leq r \leq 1$.
# - $E[R] = (n-1)/(n+1)$.
# - Simular la distribucion del rango para $n=5$ y verificar.
#
# </div>

# %%
# Tu solucion para el Ejercicio 32
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 33: Convolucion de normales independientes
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Suma de normales independientes:**
#
# Si $X \sim \mathcal{N}(3, 4)$ y $Y \sim \mathcal{N}(5, 9)$ son independientes, entonces:
#
# $$Z = X + Y \sim \mathcal{N}(3+5, 4+9) = \mathcal{N}(8, 13)$$
#
# - Las medias se suman y las varianzas se suman (por independencia).
# - Verificar con simulacion y con la convolucion numerica de las PDFs.
# - Esta propiedad reproductiva es exclusiva de la normal.
#
# </div>

# %%
# Tu solucion para el Ejercicio 33
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 34: Distribucion Erlang como suma de exponenciales
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Erlang(k, lambda) = suma de k Exp(lambda):**
#
# Si $X_1, \ldots, X_k \sim \text{Exp}(\lambda)$ independientes, entonces $S = \sum X_i \sim \text{Erlang}(k, \lambda)$.
#
# - Para $k=5$, $\lambda=2$, simular la suma y comparar con $\text{Gamma}(k, 1/\lambda)$.
# - La Erlang es un caso especial de la Gamma con parametro de forma entero.
# - Modela el tiempo hasta el $k$-esimo evento en un proceso de Poisson.
#
# </div>

# %%
# Tu solucion para el Ejercicio 34
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 35: CDF empirica y banda de confianza DKW
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Desigualdad de Dvoretzky-Kiefer-Wolfowitz:**
#
# La banda DKW proporciona un intervalo de confianza uniforme para la CDF:
#
# $$P\left(\sup_x |F_n(x) - F(x)| > \varepsilon\right) \leq 2 e^{-2n\varepsilon^2}$$
#
# - Para nivel $\alpha$: $\varepsilon = \sqrt{\frac{\ln(2/\alpha)}{2n}}$.
# - Graficar $F_n(x)$ con la banda DKW al 95% de confianza.
# - Verificar que $F(x)$ queda dentro de la banda.
#
# </div>

# %%
# Tu solucion para el Ejercicio 35
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 36: Copula gaussiana bivariada
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Generar dependencia con copula gaussiana:**
#
# - Generar una normal bivariada con correlacion $\rho = 0.7$.
# - Transformar las marginales a uniformes usando la CDF normal (copula).
# - La copula captura la estructura de dependencia independientemente de las marginales.
# - Visualizar tanto el espacio normal como el espacio de la copula.
#
# </div>

# %%
# Tu solucion para el Ejercicio 36
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 37: Metodo Box-Muller
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Generar normales desde uniformes:**
#
# El metodo Box-Muller transforma dos uniformes independientes en dos normales estandar:
#
# $$Z_1 = \sqrt{-2\ln U_1} \cos(2\pi U_2), \quad Z_2 = \sqrt{-2\ln U_1} \sin(2\pi U_2)$$
#
# - Generar 10000 pares de normales estandar.
# - Verificar que ambas son $\mathcal{N}(0,1)$ e independientes.
# - Es la transformacion inversa de coordenadas polares (ejercicio 25).
#
# </div>

# %%
# Tu solucion para el Ejercicio 37
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 38: Normal multivariada 2D
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Normal bivariada con covarianza:**
#
# Generar datos de $\mathcal{N}\left(\boldsymbol{\mu}, \boldsymbol{\Sigma}\right)$ con:
#
# $$\boldsymbol{\mu} = \begin{pmatrix} 3 \\ 5 \end{pmatrix}, \quad \boldsymbol{\Sigma} = \begin{pmatrix} 4 & 2 \\ 2 & 9 \end{pmatrix}$$
#
# - Visualizar el scatter con curvas de nivel de la densidad.
# - Verificar las marginales: $X_1 \sim \mathcal{N}(3, 4)$, $X_2 \sim \mathcal{N}(5, 9)$.
# - Correlacion: $\rho = 2/\sqrt{4 \cdot 9} = 1/3$.
#
# </div>

# %%
# Tu solucion para el Ejercicio 38
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 39: Elipse de confianza al 95% para normal bivariada
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Region de confianza bivariada:**
#
# Para una normal bivariada, la elipse de confianza al nivel $1-\alpha$ esta definida por:
#
# $$(\mathbf{x} - \boldsymbol{\mu})^T \boldsymbol{\Sigma}^{-1} (\mathbf{x} - \boldsymbol{\mu}) \leq \chi^2_2(\alpha)$$
#
# - El umbral para 95% es $\chi^2_2(0.05) = 5.991$.
# - Graficar la elipse y verificar que contiene aproximadamente el 95% de los datos.
# - Los semiejes de la elipse son $\sqrt{\lambda_i \cdot \chi^2_2(\alpha)}$ donde $\lambda_i$ son los eigenvalores.
#
# </div>

# %%
# Tu solucion para el Ejercicio 39
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 40: Distancia de Mahalanobis y deteccion de outliers
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Deteccion de anomalias en datos 2D:**
#
# - Generar datos normales bivariados con algunos outliers.
# - Calcular la distancia de Mahalanobis para cada punto.
# - $D^2_M = (\mathbf{x}-\boldsymbol{\mu})^T \boldsymbol{\Sigma}^{-1} (\mathbf{x}-\boldsymbol{\mu}) \sim \chi^2_2$.
# - Clasificar como outlier si $D^2_M > \chi^2_2(0.01) = 9.21$.
#
# </div>

# %%
# Tu solucion para el Ejercicio 40
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 41: Chi-cuadrado como suma de normales al cuadrado
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Construccion de la chi-cuadrado:**
#
# Si $Z_1, \ldots, Z_k \sim \mathcal{N}(0,1)$ independientes, entonces:
#
# $$Q = \sum_{i=1}^k Z_i^2 \sim \chi^2(k)$$
#
# - Simular $\chi^2(k)$ para $k = 1, 3, 5, 10$ sumando normales al cuadrado.
# - Comparar con `scipy.stats.chi2`.
# - $E[\chi^2(k)] = k$, $\text{Var}[\chi^2(k)] = 2k$.
#
# </div>

# %%
# Tu solucion para el Ejercicio 41
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 42: Distribucion t de Student desde N(0,1) y Chi2
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Construccion de la t de Student:**
#
# Si $Z \sim \mathcal{N}(0,1)$ y $V \sim \chi^2(k)$ son independientes, entonces:
#
# $$T = \frac{Z}{\sqrt{V/k}} \sim t(k)$$
#
# - Simular $t(k)$ para $k = 2, 5, 30$ usando la definicion.
# - Comparar con la normal estandar para ver como converge.
# - $k$ pequeno: colas mas pesadas que la normal.
#
# </div>

# %%
# Tu solucion para el Ejercicio 42
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 43: Distribucion F de Fisher desde Chi-cuadrado
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Construccion de la F de Fisher:**
#
# Si $V_1 \sim \chi^2(k_1)$ y $V_2 \sim \chi^2(k_2)$ son independientes, entonces:
#
# $$F = \frac{V_1/k_1}{V_2/k_2} \sim F(k_1, k_2)$$
#
# - Simular $F(5, 10)$ y $F(10, 30)$ desde chi-cuadrados.
# - La F aparece en ANOVA y tests de comparacion de varianzas.
# - $E[F] = k_2/(k_2-2)$ para $k_2 > 2$.
#
# </div>

# %%
# Tu solucion para el Ejercicio 43
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 44: Metodo de la inversa de la CDF para Exponencial
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Transformacion inversa:**
#
# Si $U \sim U(0,1)$, entonces $X = F^{-1}(U)$ tiene CDF $F$. Para la exponencial:
#
# $$X = -\frac{\ln(1-U)}{\lambda}$$
#
# - Implementar el metodo para $\text{Exp}(\lambda=2)$.
# - Como $1-U \sim U(0,1)$, tambien vale $X = -\ln(U)/\lambda$.
# - Comparar con `np.random.exponential`.
#
# </div>

# %%
# Tu solucion para el Ejercicio 44
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 45: Metodo de aceptacion-rechazo para Beta(2,5)
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Algoritmo de aceptacion-rechazo:**
#
# Para generar $X \sim \text{Beta}(2,5)$ usando $U(0,1)$ como distribucion propuesta:
#
# 1. Generar $X \sim U(0,1)$ y $U \sim U(0,1)$ independientes.
# 2. Calcular $M = \max f_{\text{Beta}}(x)$ (constante de acotacion).
# 3. Aceptar $X$ si $U \leq f_{\text{Beta}}(X) / (M \cdot g(X))$, donde $g$ es la PDF uniforme.
# 4. La tasa de aceptacion es $1/M$.
#
# </div>

# %%
# Tu solucion para el Ejercicio 45
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 46: Importance sampling para probabilidades raras
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Estimacion de $P(X > 3)$ para $X \sim \mathcal{N}(0,1)$:**
#
# - Monte Carlo naive: muchas muestras caen lejos de la region de interes.
# - Importance sampling con proposal $\mathcal{N}(3, 1)$: muestrear donde importa.
# - Estimador: $\hat{p} = \frac{1}{n}\sum_{i=1}^n \mathbf{1}(X_i > 3) \cdot \frac{f(X_i)}{g(X_i)}$ donde $g$ es la proposal.
# - Comparar la varianza de ambos estimadores.
#
# </div>

# %%
# Tu solucion para el Ejercicio 46
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 47: Distribucion de la varianza muestral
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Teorema fundamental:**
#
# Si $X_1, \ldots, X_n \sim \mathcal{N}(\mu, \sigma^2)$, entonces:
#
# $$\frac{(n-1)S^2}{\sigma^2} \sim \chi^2(n-1)$$
#
# - Verificar con simulacion para diferentes valores de $n$.
# - Este resultado justifica el uso de la $\chi^2$ en intervalos de confianza para $\sigma^2$.
# - $S^2$ y $\bar{X}$ son independientes (teorema de Cochran).
#
# </div>

# %%
# Tu solucion para el Ejercicio 47
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 48: Mapa de relaciones entre distribuciones
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Diagrama visual: Normal -> Chi2 -> t -> F**
#
# Construir un diagrama que muestre las relaciones fundamentales:
#
# - $Z^2 \sim \chi^2(1)$: cuadrado de una normal estandar.
# - $\sum Z_i^2 \sim \chi^2(k)$: suma de cuadrados.
# - $Z/\sqrt{V/k} \sim t(k)$: cociente con chi-cuadrado.
# - $(V_1/k_1)/(V_2/k_2) \sim F(k_1, k_2)$: cociente de chi-cuadrados.
# - $T^2 \sim F(1, k)$: cuadrado de t es F.
#
# </div>

# %%
# Tu solucion para el Ejercicio 48
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 49: Estimacion MLE de parametros Weibull
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Maxima verosimilitud para Weibull:**
#
# Dados datos de tiempos de fallo, estimar los parametros $k$ y $\lambda$ de una distribucion Weibull usando MLE:
#
# - Generar datos de $\text{Weibull}(k=1.5, \lambda=500)$.
# - La log-verosimilitud es: $\ell(k,\lambda) = n\ln k - nk\ln\lambda + (k-1)\sum\ln x_i - \sum(x_i/\lambda)^k$.
# - Optimizar con `scipy.optimize.minimize`.
# - Comparar estimaciones con los parametros verdaderos.
#
# </div>

# %%
# Tu solucion para el Ejercicio 49
# Escribe tu codigo aqui

# %% [markdown]
# ## Ejercicio 50: Test de Anderson-Darling vs Kolmogorov-Smirnov
#
# <div style="border-left:4px solid #3498db; padding:10px 15px; margin:10px 0; background:#f8f9fa;">
#
# **Comparacion de tests de bondad de ajuste:**
#
# - El test de Anderson-Darling (AD) da mas peso a las colas que el KS.
# - Comparar ambos tests en su capacidad de detectar desviaciones en las colas.
# - El estadistico AD es: $A^2 = -n - \frac{1}{n}\sum_{i=1}^n (2i-1)[\ln F(x_i) + \ln(1-F(x_{n+1-i}))]$.
# - Usar `scipy.stats.anderson` y `scipy.stats.kstest`.
#
# </div>

# %%
# Tu solucion para el Ejercicio 50
# Escribe tu codigo aqui
